# %%
#Import Libraries
import spacy
from spacy import displacy
from collections import Counter
import en_core_web_sm
import nltk
import string
import pandas as pd
import re
import os 

# Download Spacy package if needed.
#python -m spacy download en_core_web_sm


# Download Tokenizer package if needed.
#nltk.download('punkt')

# Import and load NLTK
import nltk.data
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')

# %%
# Configure Pandas Viewing Window
pd.set_option('display.max_rows', 500)
pd.set_option('display.width', 5000)
pd.set_option('display.expand_frame_repr', False)
pd.set_option('display.max_column',None)
pd.set_option('display.width', 5000)
pd.set_option('display.max_colwidth', -1)

# %%
# Set range to search for prices within.
lower_threshold = 30
upper_threshold = 450


# Set Constants to search for.l
integers = ["1", "2", "3", "4", "5", "6", "7", "8", "9" ]

units = [
        "zero", "one", "two", "three", "four", "five", "six", "seven", "eight",
        "nine", "ten", "eleven", "twelve", "thirteen", "fourteen", "fifteen",
        "sixteen", "seventeen", "eighteen", "nineteen"
    ]

tens = ["", "twenty", "thirty", "forty", "fifty", "sixty", "seventy", "eighty", "ninety"]

scales = ["hundred", "thousand", "million", "billion", "trillion"]


doc_check_keys = ["a", "and", "dollars", "cents", "cent", "dollar"]



# Build dictionary with mode price of each package. 
no_package_moce_price = {'NO PRODUCTS': 4.99}

single_package_mode_price = {'VIDEO ONLY': 49.99, 'CDV ONLY': 29.99, 'XM ONLY': 30.00, 'HSD ONLY': 39.99
                            , 'XH ONLY' : 24.99
    
}

double_package_mode_price = {'HSD/XH': 39.99 , 'HSD/CDV': 59.99 , 'CDV/XH': 19.99, 'XH/XM': 24.99,
                            'VIDEO/CDV': 74.99 , 'CDV/XM': 25.00, 'VIDEO/XM': 54.99, 'HSD/XM': 39.99 , 
                            'VIDEO/XH': 29.99 , 'VIDEO/HSD': 49.99 
}

triple_package_mode_price = {'VIDEO/CDV/XH': 24.99 , 'VIDEO/HSD/XM': 89.99 , 'HSD/CDV/XM': 59.99 ,
                            'CDV/XH/XM': 24.10 , 'VIDEO/HSD/XH': 109.99 , 'HSD/XH/XM': 39.99 , 
                            'VIDEO/HSD/CDV': 119.99 , 'HSD/CDV/XH': 59.99 , 
                            'VIDEO/CDV/XM': 54.99, 'VIDEO/XH/XM': 24.99
                            
    
}

quad_package_mode_price = {'VIDEO/HSD/XH/XM': 109.99, 'VIDEO/HSD/CDV/XH': 24.99, 'HSD/CDV/XH/XM': 29.95, 
                          'VIDEO/CDV/XH/XM': 24.99, 'VIDEO/HSD/CDV/XM': 119.99
    
}

# Form large dictionary out of various packages.

master_price_dict = {19.99: 'CDV/XH',
               24.10: 'CDV/XH/XM', 
               24.99: ('XH ONLY', 'XH/XM', 'VIDEO/CDV/XH', 'VIDEO/XH/XM',
                       'VIDEO/HSD/CDV/XH', 'VIDEO/CDV/XH/XM', 'CDV/XM'), 
                29.99: ('HSD/CDV/XH/XM', 'CDV ONLY', 'VIDEO/XH', 'XM ONLY'), 
               39.99: ('HSD ONLY', 'HSD/XH', 'HSD/XM', 'HSD/XH/XM'), 
               49.99: ('VIDEO ONLY', 'VIDEO/HSD'), 
               54.99: ('VIDEO/XM', 'VIDEO/CDV/XM'), 
               59.99: ('HSD/CDV', 'HSD/CDV/XM', 'HSD/CDV/XH'), 
               74.99: 'VIDEO/CDV', 
               89.99: 'VIDEO/HSD/XM', 
               109.99: ('VIDEO/HSD/XH', 'VIDEO/HSD/XH/XM'), 
               119.99: ('VIDEO/HSD/CDV', 'VIDEO/HSD/CDV/XM')
              }
               

# Form sorted list of all potential prices. 
price_list = [19.99, 24.10, 24.99, 29.99, 39.99, 49.99, 54.99, 59.99, 74.99, 89.99, 109.99, 119.99]


# Form text transformation dictionary.
text_transformation_dic={'home security system':'home-security-system',\
     'security system':'security-system',\
     'home security':'home-security',
     'set top box':'set-top-box',\
     'xfinity mobile':'xfinity-mobile',\
     'infinity mobile':'xfinity-mobile',\
     'land line':'landline',\
     'home phone':'home-phone',\
     'hot spot':'hotspot',\
     'home phones':'home-phone',\
     'quad play':'quad-play',\
     'double play':'double-play',\
     'triple play':'triple-play',\
     'single play':'single-play',\
     'performance pro':'performance-pro',\
     'performance plus':'performance-plus',\
     'performance starter':'performance-starter',\
     'amazon prime': 'amazon-prime',\
     'sling tv':'sling-tv',\
     'direct tv':'direct-tv',\
     'high definition':'high-definition', \
     '1': 'one', \
     '2': 'two', \
     '3': 'three', \
     '4': 'four', \
     '5': 'five', \
     '6': 'six', \
     '7': 'seven', \
     '8': 'eight', \
     '9': 'nine'

                         
                        
                         
    }


# Form list of keywords that if found, will impact score of price negatively. 
estimates = ['about', 'around', 'almost', 'nearly', 'between', 'approaching']
post_num = ['bytes', 'byte', 'megabytes', 'megabyte', 'gigabytes', 'gigabyte', 
            'terabytes', 'terabyte', 'channels', 'channel', 'charge', 'credit']

# Form list of keywords that if found, will impact score of price positively. 
key_num1 = 'ninety nine'
key_num2 = 'ninety five' 
key_words1 = ['package', 'promotion', 'offer', 'offering', 'bundle', 'bundles', 'month', 
              'bundled', 'promotions', 'promotional', 'premium', 'premiums', 'equipment', 'equipments']

    
    
    
      
# Form list of keywords associated with each line of business.  
hsd=['speed','internet','megabyte','megabytes','megabits','modem','gigabytes','signal','wifi','network','router']
video=['tv','TV','channel','channels','set-top-box','dvr','hd','hbo','espn','box','boxes']
cdv=['landline','home-phone']
xm=['mobile','lines','hotspot','spot','xfinity-mobile', 'voice']
xh=['security-system','home-security-system','home-security-system','home-security','security','camera','cameras',
    'homeservices']

# Form additional categorical keywords. 
stream=['streaming','stream', 'livestreaming', 'streamlined']
ott=['netflix','hulu','roku']
hsd_tier=['blast','performance','performance-pro','performance-plus','performance-starter','gigabit']
vid_tier=['latino','dvr','hd','high-definition', 'sport', 'sports', 'sporting']
packages=['quad-play','double-play','triple-play','single-play']

# Load NLP
nlp = en_core_web_sm.load()

# %%
# Inputs: String, Dictionary
# Purpose: Replaces all text founds as key within dictionary with its approiate value. 
# Returns: String

def replace_all(text, dic):
    for i, j in dic.items():
        src_str  = re.compile(i, re.IGNORECASE)
        text = src_str.sub(j,text)
    return text

# %%
# Inputs: String, Dictionary
# Purpose: Converts alphabetical numeric representation to float. 
# Returns: Integer

def text2int(textnum, numwords={}):
    
    # Put everything in lower case, strip commas, and call missing_category_check on textnum. 
    textnum = textnum.lower()
    textnum = textnum.replace(',', '')
    textnum = missing_category_check(textnum)

    # Made True upon finding keywords from 'descriptors'
    take_ave = False 
    waiting_for_and = False
    
    # Stores values for calculating averages with 'to' and 'between' cases.
    keep = [] 

    # List of non number keywords to look for.
    descriptors = ['a', 'to', 'between','dollars', 'cents']
      
    if not numwords:   
      numwords["and"] = (1, 0)
      for idx, word in enumerate(units):
          numwords[word] = (1, idx)
      for idx, word in enumerate(tens):
          numwords[word] = (1, (idx+1) * 10 )
      for idx, word in enumerate(scales):  
          numwords[word] = (10 ** (idx * 3 or 2), 0)
        
    current = result = 0
    
    # For each word test if in 'descriptors or if a number word.'
    for word in textnum.split():
        if word not in numwords and word not in descriptors:
            continue 
            
        # 'a' in a number clause symbolizes '1'
        if word == 'a': 
            word = 'one' 
            
        # 'to' compares two values. When found will calculate average of two. 
        elif word == 'to': 
            take_ave = True 
            keep.append(current) 
            current = 0
            result = 0
            continue
            
        # 'between' compares two values in conjunction with 'and'. When found will calculate average of two. 
        elif word == 'between':
            waiting_for_and = True
            continue
        elif waiting_for_and and word == "and":
            waiting_for_and = False
            take_ave = True
            keep.append(current)
            current = 0
            result = 0
            continue
            
        # Anything after the word dollars needs to be treated as cents. 
        # Missing category_check will add cents to end on proper condition if speaker hasn't.  
        elif word == 'dollars':
            result = result + current 
            current = 0
            continue
            
        # Makes sure cents aren't being read as dollars. 
        elif word == 'cents':
            current = current * .01
            continue

        scale, increment = numwords[word]
        current = current * scale + increment
        if scale > 100:
            result += current
            current = 0
            
    # if 'to' or 'between' was found in clause, calculate average. Otherwise proceed normally.        
    if take_ave and keep[0] != 0: 
        return(result + current + sum(keep)) / (len(keep) + 1)
    else:
        return result + current

# %%
# Inputs: String
# Purpose: 
# Takes account for cases where speaker is speaking improperly including. 
# 1.) Not say hundred after give hundreds place 
# 2.) Saying something like thirty nine ninety nine rather than thiry nine dollars and ninety nine cents
# Returns: String

def missing_category_check(textnum):
    change_made = False
    cent_added = False
    prev_word = ''
    count = 0
    words = textnum.split()
    for word in words:
        
        # If previous word is a single digit and current word is a double digit,
        # and current word is second word in phrase treat single digit as hundred. 
        if prev_word in units and word in tens and count == 1:
            word = 'hundred ' + word
            change_made = True
            words[count] = word
        
        # If previous word is a single digit or double digit and current word is double digit, 
        # and current word is in greater postion than second, treat current phrase as cents representation. 
        elif (prev_word in units or prev_word in tens) and word in tens and count > 1:
            word = 'dollars and ' + word
            cent_added = True
            change_made = True
            words[count] = word
        prev_word = word
        count += 1

    if change_made:
        s = " ".join(words)
        if cent_added:
            s = s + " cents"
        return s
    else:
        return textnum

# %%
# Inputs: Integer, integer
# Purpose: Determines how many sentences before and after the current one we can take in for context. 
# Returns: List

def check_position(i, sentence_count):
    if i > 1:
        low = i - 2
    else: 
        low = 0
    if sentence_count - 1 - i > 1:
        high = i + 3 
    else: 
        high = sentence_count
    return([low, high])

# %%
# Inputs: String, String 
# Purpose: Gauges importanace of individual price based on price and keywords found in surround context.
# Returns: Integer

def price_importance_analysis(context, token): 
    
    # Removes all punctuation from context except for hyphens and token and splits into array.
    remove = string.punctuation.replace("-", "")
    context = context.lower().translate(str.maketrans('', '', remove))
    token = token.lower().translate(str.maketrans('', '', remove))
    
    # Default score is 0. 
    score = 0
    
    # Booleans to make sure each category only gets accounted for once. 
    estimate_found = False
    post_num_found = False
    key_words1_found = False 
    packages_found = False 
    
    # Look in context and token for above words. Token has more importance than context. 
    for word in context.split(): 
        if word in estimates and not estimate_found:
            if word in token: 
                score -= 2
            else: 
                score -= 1 
            estimate_found = True 
            continue
        if word in post_num and not post_num_found:
            if word in token: 
                score -= 2
            else: 
                score -= 1
            post_num_found = True
            continue 
        if word in key_words1 and not key_words1_found: 
            score += 2
            key_words1_found = True
            continue
        if word in packages and not packages_found:
            score += 2 
            packages_found = True
            continue

    # Ninety nine and ninety five are big indicators of package offerings. 
    if key_num1 in token or key_num2 in token:
        score += 4 
    elif key_num1 in context or key_num2 in context: 
        score += 2
    
    # Commas in token imply list of numbers. 
    if ',' in token: 
        score -= 3
    

    return score

# %%
# Inputs: Integer
# Purpose: Makes appricate guess from price dictionary if score is above threshold.
# Returns: Float

def make_guess(price):
    
    # Finds closest value in price list to given price. 
    closest_num = min(price_list, key=lambda x:abs(x-price))
    
    # Returns packages that are most commonly priced here. 
    return master_price_dict[closest_num]

# %%
# Inputs: String
# Purpose: Extracts prices and context from transcript. 
# Returns: List

def extract_info(transcript_sentences):
    i = 0 
    guess = ''
    max_score = -10
    transcript_price = 0 
    transcript_score = 0 
    transcript_context = ''
    transcript_label = []
    transcript_score = 0 
    transcript_context = '' 
    int_price = 0 
    sentence_count = len(transcript_sentences)
    
    # Search each sentence.
    while i < sentence_count:
        phrase = ""
        context_gauge = check_position(i, sentence_count) 
        lower_limit = context_gauge[0] 
        upper_limit = context_gauge[1]
        
        # Make text transformations. 
        for word in transcript_sentences[i].split():  
            word = word.lower().replace('.', '').replace('?', '')
            
            # If keyword found, calculate integer form and convert to integer.
            if word in units or word in tens or word in scales or word in doc_check_keys or word in integers:
                if len(phrase) == 0: 
                    phrase = word
                else: 
                    phrase = phrase + " " + word
            else: 
                if phrase != "": 
                    
                    # Remove 'a' and 'and' if found at end of phrase. 
                    if phrase[-1] in ('a', 'and'): 
                        phrase = phrase.rsplit(' ', 1)[0]
                    if word not in integers: 
                        int_price = text2int(phrase) 
                    else: 
                        int_price = int(phrase)
    
                price = int_price
                
            # If price within range of thresholds take context and do importance analysis. 
                if price > lower_threshold and price < upper_threshold: 
                    outer_text = str(transcript_sentences[lower_limit:1]) + str(transcript_sentences[i+1:upper_limit])
                    score = price_importance_analysis(transcript_sentences[i], phrase)
                    context = [transcript_sentences[lower_limit:i], transcript_sentences[i].upper(), transcript_sentences[i+1:upper_limit]]
                    if score >= max_score: 
                        max_score = score 
                        transcript_price = price
                        transcript_score = score 
                        transcript_context = context
                phrase = "" 
                price = 0
                int_price = 0
        i += 1
        
    # If score above threshold, make a guess of what package the pricing is associated with. 
    if transcript_score > 0: 
        guess = make_guess(transcript_price) 
    else: 
        guess = 'NONE' 
        
        # Prices formed with scores less than threhold are marked with "*"
        transcript_price = str(transcript_price) + "*"
    return [transcript_score, transcript_price, transcript_context, guess]

# %%
# Inputs: 
# Purpose: Controls file handling, text transformations, and function calling. 
# Returns: Dataframe

def main():
    rows_list = [] 
    error_count = 0 
    
    # Open necessary files
    audio_directory = "/Users/mmanle240/Downloads/nlp_git/Audio_Transcription/Amazon/Transcripts2"
    for filename in os.listdir(audio_directory): 
        if filename.endswith(".txt"):
            transcript_file_path = audio_directory + "/" + filename
            transcript_file = open(transcript_file_path, "r")
            transcript_contents = transcript_file.read().lower() 
            
            # Perform text transformations 
            transcript_contents = transcript_contents.replace(',', '')
            transcript_contents = replace_all(transcript_contents, text_transformation_dic)
            transcript_sentences = tokenizer.tokenize(transcript_contents) 
            
            # Calls rest of flow to extract dataframe. 
            data = extract_info(transcript_sentences)  
            rows_list.append(data)
            transcript_file.close() 
    df = pd.DataFrame(rows_list)
    df.columns = ['Score', 'Price', 'Context', 'Guess']
    return df

# %%
df = main()

# %%
df
# Out:
#     Score   Price                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Context                                  Guess
# 0   1      39      [[she's looking., picks it.], SHE SAID I'LL GIVE YOU A HUNDRED MEGABYTES PLUS FOR THIRTY NINE BECAUSE I HAVE TWENTY NINE DOLLARS A MONTH NOW., [not okay., she said she would work in about twenty minutes.]]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 (HSD ONLY, HSD/XH, HSD/XM, HSD/XH/XM)
# 1   0      0*                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    NONE
# 2   6      124.99  [[alright., so thank you again for being patient.], I DO HAVE THE FIRST FULL TYPE PACKAGE FOR ONE HUNDRED TWENTY FOUR DOLLARS AND NINETY NINE CENTS TO TWENTY FOUR MONTHS., [i backdated it to december twenty fourth two thousand eighteen., you'll get the uh digital er channel lineup up two hundred and fifty channels.]]                                                                                                                                                                                                                                                                                                                                                                (VIDEO/HSD/CDV, VIDEO/HSD/CDV/XM)
# 3   2      80      [[you're working now., how how much is the offer again?], UM I TRIED TO OFFER HIM THIRTY DOLLARS BUT THEY ARE ABLE TO REVIEW THE HOUSE SIXTY TWENTY AS WELL., [but on the validation um it's really a valid charge right?, yes.]]                                                                                                                                                                                                                                                                                                                                                                                                                                                             VIDEO/CDV
# 4   6      124.99  [[when you have the customer before submitting your order i want to spend a few minutes confirming with you accurately capture the services you want., i'll ask you to review the order and then if it's correct please approve it.], YOU WANT ORDERING THE X ONE FOR FOR TRIPLE TWENTY PACKAGE FOR AN INTRODUCTORY PRICE OF ONE HUNDRED TWENTY FOUR DOLLARS AND NINETY NINE CENTS PER MONTH FOR TWENTY FOUR MONTHS., [it includes digital preferred digital preferred stars stream picks digitalized outlets s v. c. did you laugh?, i hope you have a s v c. did you live out yet?]]                                                                                                        (VIDEO/HSD/CDV, VIDEO/HSD/CDV/XM)
# 5   1      90      [[looks like this is going to come out quite a little bit lower than probably what you were paying before but i've got a couple of areas here that i need to clear up., so is it okay to call you back?], UM MISS E A. I'M LOOKING AT IT BEING SOMEWHERE AROUND ABOUT EIGHTY OR NINETY DOLLARS A MONTH YOU KNOW IS WHAT I'M ESTIMATING IT TO BE CAN I CALL YOU BACK?, [is it the seven?, six five six four two six two nine zero yes i'll be there alright give me about maybe five or ten minutes and i when you back let me clear this air out for me okay?]]                                                                                                                               VIDEO/HSD/XM
# 6   4      120     [[okay i want to make sure that there isn't any extra options., yeah so that would be the best one.], IT'S A HUNDRED AND TWENTY DOLLARS A MONTH UM FOR THE TRIPLE-PLAY AND LET ME SEE ONE MORE THING., [what?, okay?]]                                                                                                                                                                                                                                                                                                                                                                                                                                                                        (VIDEO/HSD/CDV, VIDEO/HSD/CDV/XM)
# 7   2      70      [[a lincoln out that he said it a also write., you start your emails or just like it made it on when you got home so we can have this for you straight.], AND I JUST WANT TO SET THE EXPECTATION THAT TO YOUR ACCOUNT IS BEING BILLED IN EVERY SEVENTY EACH MONTH YOU CAN BUY THE WE DOWNLOAD EXPANDING THE X Y ABSOLUTELY., [she could manage your wife my name and password at the same time., once again.]]                                                                                                                                                                                                                                                                                VIDEO/CDV
# 8   6      144.99  [[and if you mean because right now up and checking here together lives easier., the phone service.], AND THEY SAID YOU'RE BEING I ON ONE FORTY FOUR NINETY NINE SO I CAN GIVE A PROMOTIONAL PRICE FOR OUR REFER BACK ISSUE FOR ONE., [twenty four ninety nine., this already includes.]]                                                                                                                                                                                                                                                                                                                                                                                                     (VIDEO/HSD/CDV, VIDEO/HSD/CDV/XM)
# 9   0      0*                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    NONE
# 10  4      195.95  [[two., service with tv dogs dvr service tv is after last internet internet voice equipment to untold your bill also includes the following the additional extremity monthly charges broadcast tv fee of six dollars and fifty cents per month regional sports fee of eight dollars and twenty five cents per month.], YOUR ESTIMATED RECURRING MONTHLY THERE WILL BE ONE HUNDRED NINETY FIVE DOLLARS AND NINETY FIVE CENTS INCLUDING EIGHT DOLLARS AND TWENTY CENTS OF ESTIMATED MOSTLY TAXES AND GOVERNMENT AND OTHER FEES YOU'RE REPLACING INCLUDES THE FOLLOWING MONTHLY DISCOUNTS., [forty dollars contract is gone for twenty four months., forty dollars to really product account.]]  (VIDEO/HSD/CDV, VIDEO/HSD/CDV/XM)
# 11  0      0*                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    NONE
# 12  0      0*                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    NONE
# 13  0      80*     [[yeah yeah there's um out the tv and there's actually um looks like an h d m i. that's plug that that then for the new one systems i guess., okay.], STILL TAKE THE EIGHTY ON MY CARD THIS AND TAKE THAT OUT AND THEY SHOULD ONLY BE ONE ONE INTO OUT TV., [and then that's going to be going into your tv., yeah and i don't know.]]                                                                                                                                                                                                                                                                                                                                                        NONE
# 14  2      90      [[i'll ask you to review the order and then if it's correct please approve it., you are ordering the following services preferred for ninety dollars per month.], THIS SERVICE AND TEENS PREFERRED SPORTS AND NEWS CHOOSE IN SANTA MARIE ENTERTAINMENT STREAM PICKS CLOUDY V R. TWENTY HOURS EXTREME OR NINETY DOLLARS PER MONTH., [service includes extreme xfinity voice for thirty dollars a month., this service in p. c d. v unlimited select primary line unlimited select you will also adding the following you put minton services four service with tv box for twenty dollars per month.]]                                                                                          VIDEO/HSD/XM
# 15  4      99      [[they come in so yeah yeah yeah., very secular.], THAT EVEN IN THE PACIFIC AT ONE THOUSAND ONE HUNDRED TO NINETY NINE AND A QUARTER., [okay eleven seven days is a radio and then the most amazing support or whatever., and come your security you almost mandatory the same message if the you see what i consider a separation.]]                                                                                                                                                                                                                                                                                                                                                         VIDEO/HSD/XM
# 16  4      84.99   [[so i guess i clicked there and it'll come up again., finidi ed choices comcast of when you do approve on a few things.], AH STARTER EIGHTY FOUR NINETY NINE THE TWENTY FOUR MONTHS SEVEN., [thirty early termination stream pick included equipment services in h d. and we do have that tv body tv adapter for the service with tv box., what do those mean?]]                                                                                                                                                                                                                                                                                                                             VIDEO/HSD/XM
# 17  0      50*     [[and you can select units you know make people to fill up soon to present telephone number., but i thought you said you didn't connect.], OKAY MHM FIFTY MAY., [we just got a lot of times someone i mean yo or both., doesn't spadaro particular office?]]                                                                                                                                                                                                                                                                                                                                                                                                                                  NONE
# 18  6      99      [[so you would get the m will be um network which is that one channel um and then other sports channels., okay so that's nine eighty nine a month nine.], NINETY NINE A MONTH YET., [and the only thing i would be see will be the mlb., nothing else right?]]                                                                                                                                                                                                                                                                                                                                                                                                                                VIDEO/HSD/XM
# 19  0      59*     [[fifteen moment to his years if ever i don't let me think., okay that's right.], LAVERN C S IF I DO THAT AND NO MATTER OF FIFTY EIGHT ONE THE THE MESSAGE AT ONE., [thirty one., okay perfect.]]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             NONE
# 20  6      79.95   [[you did approve it by text., thank you for that.], UM YOUR BALANCE IS SEVENTY NINE NINETY FIVE BILLS ARE DOING THE FIFTEENTH OF EACH MONTH., [i also want to thank you for choosing comcast and being a valuable customer., you have a fantastic day and enjoy your services.]]                                                                                                                                                                                                                                                                                                                                                                                                             VIDEO/CDV
# 21  6      84.99   [[so it's going yeah., so it's c. cinemax is going to end up being twelve.], HBO IS GOING TO BE FIFTEEN SO WE'RE GONNA REMOVE CINEMAX NINE NINETY FIVE FOR H D. SO YOU'RE PAYING EIGHTY FOUR NINETY NINE FOR STARTED DOUBLE-PLAY NINE NINETY FIVE FOR HD WHICH IS NINETY FOUR NINETY FOUR., [and this is what i was going to honor for you., i have this last from a holiday special.]]                                                                                                                                                                                                                                                                                                       VIDEO/HSD/XM
# 22  4      75.95   [[i would actually need to pull up your account in order for me to see if there are any changes actually made to the account home i speaking with today seventy., okay your service address too.], SEVENTY FIVE NINETY FIVE ALSO LIKE SIXTEEN THOUSAND NINETY FOUR TO THREE THREE ONE FOUR SEVEN FRIDAY TO VERIFY THE ACCOUNT LAST FOR THE SOCIAL SIX SEVEN NINE EIGHT IS THE MAXIMUM SO SHE THANK YOU ONE MOMENT WHILE I PULL UP THE ACCOUNT., [so., alrighty.]]                                                                                                                                                                                                                             VIDEO/CDV
# 23  6      159.95  [[and then one twenty nine ninety nine for the bundle package from uh twelve three twenty four., that's a promotion for the service.], UM RIGHT NOW YOUR RATE FOR YOUR BUNDLES ONE FIFTY NINE NINETY FIVE NOT INCLUDING ANY EQUIPMENT THEY'RE CHARGING., [taxes are feet., so that's the portion of the bill i'm discussing.]]                                                                                                                                                                                                                                                                                                                                                                (VIDEO/HSD/CDV, VIDEO/HSD/CDV/XM)
# 24  6      99      [[yes five ninety nine before., but for two thousand nineteen it's for six.], NINETY NINE EVERY MONTH., [how i have a problem with that because i have another property., uh and i use spectrum in another property that i have in orlando and i've never i haven't had increases like that.]]                                                                                                                                                                                                                                                                                                                                                                                                VIDEO/HSD/XM
# 25  2      75      [[and then you have your modem of thirteen dollars., now with this sent it does include broadcast fee which transmitting of the services for the stream tv.], SO YOU'LL BE LOOKING AT SEVENTY FIVE DOLLARS A MONTH WITH THIS ONE IS THAT WOULD ACTUALLY WHENEVER YES., [uh-huh., okay that's about twenty dollars paper than what i'm paying right?]]                                                                                                                                                                                                                                                                                                                                         VIDEO/CDV
# 26  2      70      [[the only thing is because there's the self insulation., will have to get a installation technician out there which is seven.], I MEAN YEAH SEVENTY DOLLARS TOWARDS THE NEXT MONTH., [billing., hi.]]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        VIDEO/CDV
# 27  6      84.99   [[oh four., okay so i have a package that i can take your starter channel lineup down to seventy nine ninety nine further monday.], I'M SORRY EIGHTY FOUR NINETY NINE FOR YOUR BUNDLE., [um you still have your ten dollars for your high deaf and i can add to prefer channels on there too as well., and you'd be at the same price you are now with the upgraded channels.]]                                                                                                                                                                                                                                                                                                               VIDEO/HSD/XM
# 28  6      119.99  [[i'll ask you to review the order and then if it's correct please approve it., you are doing the x one.], PREFER TRIPLE TWENTY PACKAGE FOR IN IN TWO TO THREE PRICE OF ONE HUNDRED NINETEEN DOLLARS AND NINETY NINE CENTS PER MONTH FOR TWENTY FOUR MONTHS., [it includes did you can preferred digital preferred stars stream picks service with tv dogs last internet c b the unlimited primary line., you were also adding the following equipment and services internet voice equipment to rental for thirteen dollars per month.]]                                                                                                                                                      (VIDEO/HSD/CDV, VIDEO/HSD/CDV/XM)
# 29  0      0*                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    NONE
# 30  2      78      [[you may maybe come along and they normally are thinking okay let's i i i don't know., okay so you're calling to implement a german so i'm into i went on the places you know not an explosive.], ANY KIND OF LIKE YOU DON'T THINK THE CASE BECAUSE I'M GOING TO LOOK IN A WEEK OR A MONTH LONG OF SEVENTY EIGHT MEDICAL PERSON A PERSON?, [nothing., nothing.]]                                                                                                                                                                                                                                                                                                                             VIDEO/CDV
# 31  0      0*                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    NONE
# 32  6      59.99   [[so forty ninety nine it's basically um the base rate of your internet and streaming and right amber um the twelve month it would be it would be action e. it would be a great., it would change from forty nine ninety nine to fifty nine ninety nine.], SO WE JUST HAVE TO ADD TEN DOLLARS ON TOP OF THAT SO THE REGULAR RATE WILL ONLY BE APPLY RIGHT AFTER SINCE THE PROMOTION IS GOOD FOR TWELVE MONTHS UM ON THE EIGHTH MONTH FROM FORTY NINE NINETY NINE IT WOULD BE FIFTY NINE NINETY NINE AND RIGHT AFTER THE EIGHTEEN MONTHS., [that's where the regular rates apply., that would be seventy nine eighty five.]]                                                                   (HSD/CDV, HSD/CDV/XM, HSD/CDV/XH)
# 33  6      154.99  [[and by the way sure that is amounted too., let me go ahead and double check.], UM THAT IS AMOUNTED TO A HUNDRED AND FIFTY FOUR DOLLARS AND NINETY NINE PLUS FIFTY CENT TAXES A HUNDRED AND FIFTY FOUR DOLLARS AND NINETY NINE CENTS A MONTH., [four., and that includes that will include um actually oh channels and also stars and show time and that's it.]]                                                                                                                                                                                                                                                                                                                             (VIDEO/HSD/CDV, VIDEO/HSD/CDV/XM)
# 34  6      159.99  [[yeah., so your boxes other one making your account high.], I THINK IF YOU GET BACK POCKET OF ONE FIFTY NINE NINETY NINE MHM THAT WOULD HAVE A BETTER VALUE BECAUSE YOU DON'T HAVE TO PAY FOR THE DVR SAFE WITH AAA AND YOU HAVE THE PREMIUMS., [okay so i will get it at you on cinemax then you're not off all all the uh all the china., okay.]]                                                                                                                                                                                                                                                                                                                                          (VIDEO/HSD/CDV, VIDEO/HSD/CDV/XM)
# 35  0      0*                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    NONE
# 36  0      100*    [[look at eleven., just to keep you in the middle of winter.], UH WHEN IT'S ALL OVER A HUNDRED AT THE END THAT GOING OUT TO YOU?, [okay you're okay with his political at least to connect today and your legal putting political area., okay.]]                                                                                                                                                                                                                                                                                                                                                                                                                                              NONE
# 37  1      200     [[forty seven., ninety.], UH WHAT IT'S GOING TO GIVE YOU IS UM THAT PARTICULAR PACKAGE AH ACTUALLY HAS TWO HUNDRED PLUS CHANNELS ON IT BUT IT'S GOT SOME OF MY FAVORITE CHANNELS BECAUSE IT'S GOT THINGS LIKE I LIKE SMITHSONIAN AND HISTORY AND THINGS LIKE THAT UM THE ON COURT MOVIE CHANNELS THE OLDER MOVIES AND STUFF THERE IN THEIR UH THEIR HAPPENED TO BE IN THIS PACKAGE., [uh and then if i add the see the hd is included with that so that i can drop that h t v. you're only paying ten dollars for your dvr green ticks you know?, yeah.]]                                                                                                                                     (VIDEO/HSD/CDV, VIDEO/HSD/CDV/XM)
# 38  6      62.99   [[see?, now you can do the performance internet be with the package that i offered to you without upgrading your internet.], UM IT'LL BE SIXTY TWO NINETY NINE A MONTH LEFT A FIFTY TWO SIXTY TWO BECAUSE OTHERWISE YOU'LL BE LOOKING AT TWO NINETY FIVE., [yes., if you go lower performance internet it'll be at two.]]                                                                                                                                                                                                                                                                                                                                                                     (HSD/CDV, HSD/CDV/XM, HSD/CDV/XH)
# 39  6      59.99   [[um i mean i haven't done the order yet., i just clicked it.], UM SO I'LL BE FIFTY NINE NINETY NINE FOR THE PACKAGE., [you get your choice of stars or show time and then the secondary box you have it's six ninety nine currently right now but because you're downgrading to just basic cable with this plan that secondary box would go to free., you'd be looking at your sixty nine ninety nine plus tax  and that would comes to let me see.]]                                                                                                                                                                                                                                        (HSD/CDV, HSD/CDV/XM, HSD/CDV/XH)
# 40  6      94.99   [[thirty five ninety nine week., and then you do pay extra to have hd and those sorts thing.], SO WHAT I'M DOING IS UNBUNDLING IT ALL TOGETHER BRINGING THAT PACKAGE PRICING DOWN TO THE NINETY FOUR NINETY NINE WHERE IT DOES BRING THE MONTHLY BILL DOWN TO ONE., [forty six seventeen after the government taxes and everything mhm., and and the seasonal plan.]]                                                                                                                                                                                                                                                                                                                         VIDEO/HSD/XM
# 41  6      99      [[and uh this bond., the packages normally build that array of um one hundred fifty nine dollars ninety nine cent before any additional equipment or taxes are added.], UH BUT YOU HAVE THIS UH PACKAGE AT A RATE OF ONE HUNDRED FOUR DOLLARS UH NINETY NINE CENT MAINLY BECAUSE UH YOU HAD OPTED IN UH TO A TWENTY FOUR MONTHS UH PROMOTIONAL DO UH BACK IN UH SEPTEMBER OF TWO THOUSAND SEVENTEEN., [uh i mean it's due to mature on september uh twenty third of two thousand nineteen which is this year., um so as of right now i don't have a solution for uh reducing a monthly recurring charges.]]                                                                                   VIDEO/HSD/XM
# 42  4      49.99   [[match them., resign.], AND I FOUND IT FOR THEM IS ON FOR FORTY NINE NINETY NINE AND THEY THEY PROBABLY MATCHED IT., [alright., want want background?]]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      (VIDEO ONLY, VIDEO/HSD)
# 43  6      49.99   [[and not only that., bye.], THEY TOLD ME THAT THAT PACKAGE OR WHATEVER THAT OFFER INITIALLY WHAT THE FORTY NINE NINETY NINE OFFER LAST?, [because i you know i don't want to we you know we're in a temporary housing i cannot do with two year agreement., you know the the pricing of that went up to sixty nine ninety nine last taxes and all that all together plus the gig and all that.]]                                                                                                                                                                                                                                                                                             (VIDEO ONLY, VIDEO/HSD)
# 44  0      60*     [[but advantis it will go back on and once it's fully registers then we will check again if you will be getting uh enough signal okay?, almost done here.], IT'S ALREADY AT SIXTY PERSON., [okay?, okay?]]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    NONE
# 45  6      95      [[and if you can't do that and if while can do it for ninety five i'm a full not to take it., so so that doesn't include your taxes.], AS HE'S ON THE ACCOUNT ON YOUR ADDITIONAL EQUIPMENT THE NINETY FIVE AND THEN KEEP IN MIND YOU ARE GOING TO A SLOWER INTERNET SPEED AND ALSO WITH WHILE YOU DON'T HAVE YOUR ON DEMAND AVAILABLE FOR YOU., [and i did see here that you guys are using the on demand quite a bit., um so you don't have your on demand available for you would go into the while services.]]                                                                                                                                                                             VIDEO/HSD/XM
# 46  6      125.99  [[this is by this it was toward the second., it's about nineteen  i mean.], A HUNDRED AND TWENTY FIVE NINETY NINE A MONTH., [that's how much man i got to be a month., um i can jerry that it's one ninety four sixteen man.]]                                                                                                                                                                                                                                                                                                                                                                                                                                                                (VIDEO/HSD/CDV, VIDEO/HSD/CDV/XM)

# %%
output_string = "" 
context_list = df['Context'].tolist() 
for context in context_list: 
    context = str(context)
    context = context.lower()
    context = context.translate(str.maketrans('', '', string.punctuation))
    output_string = output_string + context
print(output_string)
# Out:
# shes looking picks it she said ill give you a hundred megabytes plus for thirty nine because i have twenty nine dollars a month now not okay she said she would work in about twenty minutesalright so thank you again for being patient i do have the first full type package for one hundred twenty four dollars and ninety nine cents to twenty four months i backdated it to december twenty fourth two thousand eighteen youll get the uh digital er channel lineup up two hundred and fifty channelsyoure working now how how much is the offer again um i tried to offer him thirty dollars but they are able to review the house sixty twenty as well but on the validation um its really a valid charge right yeswhen you have the customer before submitting your order i want to spend a few minutes confirming with you accurately capture the services you want ill ask you to review the order and then if its correct please approve it you want ordering the x one for for triple twenty package for an introductory price of one hundred twenty four dollars and ninety nine cents per month for twenty four months it includes digital preferred digital preferred stars stream picks digitalized outlets s v c did you laugh i hope you have a s v c did you live out yetlooks like this is going to come out quite a little bit lower than probably what you were paying before but ive got a couple of areas here that i need to clear up so is it okay to call you back um miss e a im looking at it being somewhere around about eighty or ninety dollars a month you know is what im estimating it to be can i call you back is it the seven six five six four two six two nine zero yes ill be there alright give me about maybe five or ten minutes and i when you back let me clear this air out for me okayokay i want to make sure that there isnt any extra options yeah so that would be the best one its a hundred and twenty dollars a month um for the tripleplay and let me see one more thing what okaya lincoln out that he said it a also write you start your emails or just like it made it on when you got home so we can have this for you straight and i just want to set the expectation that to your account is being billed in every seventy each month you can buy the we download expanding the x y absolutely she could manage your wife my name and password at the same time once againand if you mean because right now up and checking here together lives easier the phone service and they said youre being i on one forty four ninety nine so i can give a promotional price for our refer back issue for one twenty four ninety nine this already includestwo service with tv dogs dvr service tv is after last internet internet voice equipment to untold your bill also includes the following the additional extremity monthly charges broadcast tv fee of six dollars and fifty cents per month regional sports fee of eight dollars and twenty five cents per month your estimated recurring monthly there will be one hundred ninety five dollars and ninety five cents including eight dollars and twenty cents of estimated mostly taxes and government and other fees youre replacing includes the following monthly discounts forty dollars contract is gone for twenty four months forty dollars to really product accountyeah yeah theres um out the tv and theres actually um looks like an h d m i thats plug that that then for the new one systems i guess okay still take the eighty on my card this and take that out and they should only be one one into out tv and then thats going to be going into your tv yeah and i dont knowill ask you to review the order and then if its correct please approve it you are ordering the following services preferred for ninety dollars per month this service and teens preferred sports and news choose in santa marie entertainment stream picks cloudy v r twenty hours extreme or ninety dollars per month service includes extreme xfinity voice for thirty dollars a month this service in p c d v unlimited select primary line u ...

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize
ps = PorterStemmer()

output_string_split = output_string.split()
for i in range(len(output_string_split)): 
    output_string_split[i] = ps.stem(output_string_split[i])


word_count_dict = {} 
for word in output_string_split: 
    if word not in word_count_dict: 
        word_count_dict[word] = 1 
    elif word in word_count_dict: 
        word_count_dict[word] += 1 

for key, value in sorted(word_count_dict.items(), key=lambda item: item[1]):
    print("%s: %s" % (key, value))
# Out:
# megabyt: 1
# minutesalright: 1
# patient: 1
# first: 1
# type: 1
# backdat: 1
# decemb: 1
# fourth: 1
# er: 1
# channelsyour: 1
# tri: 1
# him: 1
# abl: 1
# yeswhen: 1
# submit: 1
# spend: 1
# confirm: 1
# accur: 1
# captur: 1
# introductori: 1
# outlet: 1
# laugh: 1
# hope: 1
# yetlook: 1
# littl: 1
# coupl: 1
# miss: 1
# somewher: 1
# around: 1
# zero: 1
# air: 1
# okayokay: 1
# isnt: 1
# option: 1
# best: 1
# tripleplay: 1
# more: 1
# okaya: 1
# lincoln: 1
# write: 1
# email: 1
# straight: 1
# set: 1
# expect: 1
# buy: 1
# download: 1
# expand: 1
# y: 1
# absolut: 1
# could: 1
# manag: 1
# wife: 1
# name: 1
# password: 1
# againand: 1
# easier: 1
# phone: 1
# our: 1
# refer: 1
# issu: 1
# includestwo: 1
# untold: 1
# region: 1
# mostli: 1
# replac: 1
# discount: 1
# contract: 1
# gone: 1
# product: 1
# accountyeah: 1
# plug: 1
# new: 1
# system: 1
# card: 1
# should: 1
# knowil: 1
# teen: 1
# news: 1
# santa: 1
# mari: 1
# entertain: 1
# cloudi: 1
# r: 1
# hour: 1
# xfiniti: 1
# p: 1
# minton: 1
# monththey: 1
# veri: 1
# secular: 1
# even: 1
# pacif: 1
# quarter: 1
# radio: 1
# most: 1
# amaz: 1
# support: 1
# secur: 1
# mandatori: 1
# consid: 1
# separationso: 1
# finidi: 1
# ed: 1
# earli: 1
# termin: 1
# bodi: 1
# adapt: 1
# meanand: 1
# unit: 1
# peopl: 1
# fill: 1
# soon: 1
# present: 1
# telephon: 1
# number: 1
# thought: 1
# didnt: 1
# lot: 1
# someon: 1
# yo: 1
# both: 1
# spadaro: 1
# officeso: 1
# network: 1
# mlb: 1
# els: 1
# rightfifteen: 1
# ever: 1
# lavern: 1
# no: 1
# matter: 1
# perfecty: 1
# text: 1
# balanc: 1
# fifteenth: 1
# valuabl: 1
# fantast: 1
# enjoy: 1
# servicesso: 1
# hbo: 1
# fifteen: 1
# gonna: 1
# remov: 1
# doubleplay: 1
# honor: 1
# holiday: 1
# speciali: 1
# speak: 1
# address: 1
# friday: 1
# verifi: 1
# social: 1
# maximum: 1
# alrightyand: 1
# theyr: 1
# feet: 1
# portion: 1
# discussingy: 1
# problem: 1
# spectrum: 1
# orlando: 1
# never: 1
# increas: 1
# thatand: 1
# modem: 1
# sent: 1
# transmit: 1
# whenev: 1
# uhhuh: 1
# paper: 1
# rightth: 1
# self: 1
# insul: 1
# instal: 1
# technician: 1
# next: 1
# hioh: 1
# further: 1
# monday: 1
# sorri: 1
# deaf: 1
# channelsil: 1
# b: 1
# rental: 1
# monthyou: 1
# along: 1
# implement: 1
# german: 1
# place: 1
# explos: 1
# kind: 1
# case: 1
# long: 1
# medic: 1
# nothingso: 1
# base: 1
# amber: 1
# action: 1
# great: 1
# top: 1
# sinc: 1
# good: 1
# eighth: 1
# fiveand: 1
# way: 1
# ahead: 1
# doubl: 1
# oh: 1
# ityeah: 1
# pocket: 1
# better: 1
# valu: 1
# safe: 1
# aaa: 1
# premium: 1
# off: 1
# china: 1
# okaylook: 1
# middl: 1
# winter: 1
# over: 1
# least: 1
# legal: 1
# okayforti: 1
# ha: 1
# some: 1
# favorit: 1
# smithsonian: 1
# histori: 1
# court: 1
# older: 1
# stuff: 1
# happen: 1
# drop: 1
# t: 1
# green: 1
# tick: 1
# yeahse: 1
# without: 1
# left: 1
# otherwis: 1
# twoum: 1
# current: 1
# downgrad: 1
# cabl: 1
# plan: 1
# free: 1
# seethirti: 1
# sort: 1
# unbundl: 1
# everyth: 1
# season: 1
# planand: 1
# bond: 1
# build: 1
# array: 1
# mainli: 1
# opt: 1
# due: 1
# matur: 1
# third: 1
# solut: 1
# reduc: 1
# chargesmatch: 1
# resign: 1
# found: 1
# match: 1
# backgroundand: 1
# bye: 1
# told: 1
# initi: 1
# temporari: 1
# cannot: 1
# agreement: 1
# gig: 1
# thatbut: 1
# advanti: 1
# fulli: 1
# regist: 1
# enough: 1
# signal: 1
# okayand: 1
# cant: 1
# mind: 1
# slower: 1
# speed: 1
# guy: 1
# servicesthi: 1
# second: 1
# jerri: 1
# work: 2
# full: 2
# eighteen: 2
# lineup: 2
# much: 2
# hous: 2
# well: 2
# valid: 2
# realli: 2
# custom: 2
# few: 2
# minut: 2
# tripl: 2
# live: 2
# quit: 2
# bit: 2
# lower: 2
# than: 2
# probabl: 2
# ive: 2
# area: 2
# need: 2
# clear: 2
# e: 2
# alright: 2
# mayb: 2
# sure: 2
# extra: 2
# he: 2
# start: 2
# made: 2
# home: 2
# everi: 2
# each: 2
# onc: 2
# alreadi: 2
# dog: 2
# broadcast: 2
# recur: 2
# govern: 2
# m: 2
# guess: 2
# still: 2
# choos: 2
# primari: 2
# line: 2
# put: 2
# eleven: 2
# day: 2
# whatev: 2
# almost: 2
# messag: 2
# click: 2
# choic: 2
# comcast: 2
# ah: 2
# starter: 2
# those: 2
# connect: 2
# may: 2
# doesnt: 2
# particular: 2
# yet: 2
# noth: 2
# moment: 2
# hi: 2
# end: 2
# wa: 2
# pull: 2
# chang: 2
# today: 2
# sixteen: 2
# anoth: 2
# properti: 2
# use: 2
# havent: 2
# had: 2
# thirteen: 2
# doe: 2
# toward: 2
# high: 2
# youd: 2
# upgrad: 2
# normal: 2
# went: 2
# week: 2
# basic: 2
# regular: 2
# appli: 2
# where: 2
# amount: 2
# show: 2
# keep: 2
# polit: 2
# movi: 2
# their: 2
# perform: 2
# done: 2
# secondari: 2
# bring: 2
# seventeen: 2
# septemb: 2
# them: 2
# avail: 2
# man: 2
# youll: 3
# charg: 3
# ask: 3
# correct: 3
# pleas: 3
# x: 3
# an: 3
# s: 3
# call: 3
# estim: 3
# ye: 3
# make: 3
# my: 3
# same: 3
# check: 3
# togeth: 3
# dvr: 3
# voic: 3
# addit: 3
# extrem: 3
# sport: 3
# other: 3
# unlimit: 3
# select: 3
# ad: 3
# itll: 3
# mhm: 3
# year: 3
# by: 3
# cinemax: 3
# hd: 3
# too: 3
# bundl: 3
# down: 3
# add: 3
# person: 3
# demand: 3
# ill: 4
# give: 4
# thank: 4
# again: 4
# how: 4
# review: 4
# as: 4
# befor: 4
# star: 4
# were: 4
# here: 4
# ten: 4
# when: 4
# time: 4
# promot: 4
# after: 4
# fee: 4
# h: 4
# d: 4
# take: 4
# into: 4
# think: 4
# twelv: 4
# from: 4
# three: 4
# while: 4
# nineteen: 4
# pick: 5
# said: 5
# plu: 5
# thirti: 5
# about: 5
# digit: 5
# offer: 5
# approv: 5
# v: 5
# did: 5
# ani: 5
# follow: 5
# monthli: 5
# eight: 5
# box: 5
# which: 5
# rate: 5
# she: 6
# not: 6
# thousand: 6
# sixti: 6
# price: 6
# stream: 6
# c: 6
# come: 6
# pay: 6
# got: 6
# let: 6
# see: 6
# bill: 6
# mean: 6
# last: 6
# actual: 6
# onli: 6
# look: 7
# get: 7
# they: 7
# back: 7
# eighti: 7
# seven: 7
# thing: 7
# just: 7
# we: 7
# account: 7
# equip: 7
# but: 8
# order: 8
# per: 8
# prefer: 8
# know: 8
# six: 8
# yeah: 8
# also: 8
# tax: 8
# all: 8
# now: 9
# channel: 9
# up: 9
# right: 9
# want: 9
# out: 9
# like: 9
# im: 9
# me: 9
# seventi: 9
# forti: 9
# internet: 9
# dont: 9
# what: 10
# or: 10
# becaus: 11
# cent: 11
# are: 11
# there: 11
# will: 11
# can: 12
# tv: 12
# packag: 13
# includ: 13
# do: 14
# two: 14
# fifti: 14
# if: 14
# hundr: 15
# then: 15
# at: 15
# would: 16
# go: 16
# with: 17
# servic: 17
# thi: 17
# okay: 18
# five: 18
# in: 20
# on: 20
# uh: 21
# um: 24
# have: 25
# twenti: 25
# four: 27
# of: 27
# so: 28
# is: 28
# dollar: 29
# one: 30
# month: 32
# be: 33
# your: 39
# for: 47
# it: 51
# a: 52
# nineti: 53
# that: 55
# nine: 59
# i: 61
# to: 61
# you: 73
# and: 79
# the: 96

# %%
audio_directory = "/Users/mmanle240/Downloads/nlp_git/Audio_Transcription/Amazon/Transcripts2"
all_transcripts = ""
transcript_dict = {} 
for filename in os.listdir(audio_directory): 
    if filename.endswith(".txt"):
        transcript_file_path = audio_directory + "/" + filename
        transcript_file = open(transcript_file_path, "r")
        transcript_contents = transcript_file.read().lower().translate(str.maketrans('', '', string.punctuation))
        all_transcripts = all_transcripts + transcript_contents
all_transcripts_split = all_transcripts.split()  
for i in range(len(all_transcripts_split)): 
    all_transcripts_split[i] = ps.stem(all_transcripts_split[i])
for word in all_transcripts_split: 
    if word not in transcript_dict: 
        transcript_dict[word] = 1 
    elif word in transcript_dict: 
        transcript_dict[word] += 1
for key, value in sorted(transcript_dict.items(), key=lambda item: item[1]):
    print("%s: %s" % (key, value))
# Out:
# boot: 1
# attempt: 1
# soft: 1
# stabil: 1
# repress: 1
# achiev: 1
# straighten: 1
# rightthank: 1
# sarah: 1
# race: 1
# instil: 1
# pace: 1
# huge: 1
# cynic: 1
# amp: 1
# vote: 1
# bridg: 1
# rerun: 1
# moca: 1
# task: 1
# result: 1
# sro: 1
# goin: 1
# gogood: 1
# jennif: 1
# brize: 1
# attend: 1
# arculli: 1
# steal: 1
# tarp: 1
# retent: 1
# ivr: 1
# morgan: 1
# nawawi: 1
# austin: 1
# fiction: 1
# frustrat: 1
# writer: 1
# clean: 1
# changeabl: 1
# lettuc: 1
# basket: 1
# dead: 1
# proof: 1
# passport: 1
# absenc: 1
# confid: 1
# screenshot: 1
# instantli: 1
# momentarili: 1
# voluntarili: 1
# airhead: 1
# pam: 1
# confirmatori: 1
# neighbor: 1
# preview: 1
# profess: 1
# comedian: 1
# dictat: 1
# immun: 1
# supervis: 1
# easter: 1
# chine: 1
# philippin: 1
# realiz: 1
# manual: 1
# licens: 1
# novat: 1
# kenneth: 1
# ty: 1
# defect: 1
# disput: 1
# valley: 1
# georg: 1
# troop: 1
# investig: 1
# ansel: 1
# scf: 1
# forit: 1
# mix: 1
# harmon: 1
# van: 1
# si: 1
# lump: 1
# xt6: 1
# invis: 1
# dec: 1
# morbid: 1
# mornin: 1
# backup: 1
# anag: 1
# taki: 1
# worn: 1
# bind: 1
# eah: 1
# cloudier: 1
# compli: 1
# mortgag: 1
# mikey: 1
# frick: 1
# lew: 1
# grandpar: 1
# vester: 1
# gen: 1
# roughest: 1
# fir: 1
# frantic: 1
# pacifi: 1
# motorman: 1
# ignor: 1
# surround: 1
# nowy: 1
# tyron: 1
# anderson: 1
# warmer: 1
# porch: 1
# milk: 1
# serio: 1
# cathi: 1
# nowaday: 1
# escal: 1
# elsewher: 1
# struggl: 1
# catherin: 1
# katherin: 1
# progress: 1
# scroll: 1
# underneath: 1
# freer: 1
# rare: 1
# altern: 1
# deposit: 1
# eas: 1
# buthi: 1
# travi: 1
# jaquelyn: 1
# polic: 1
# credenti: 1
# latex: 1
# viavoic: 1
# respect: 1
# illington: 1
# wipe: 1
# newport: 1
# hijack: 1
# secret: 1
# weight: 1
# classifi: 1
# eye: 1
# jackley: 1
# frasier: 1
# unlik: 1
# procedur: 1
# skip: 1
# accordingli: 1
# luggag: 1
# bicep: 1
# delay: 1
# cash: 1
# weak: 1
# straight: 1
# alex: 1
# wanda: 1
# warren: 1
# feed: 1
# cage: 1
# motion: 1
# disturb: 1
# summeri: 1
# profit: 1
# sashri: 1
# dcd: 1
# spaciou: 1
# mainathank: 1
# glenview: 1
# fixabl: 1
# mistak: 1
# cereal: 1
# ou: 1
# mumbl: 1
# nest: 1
# standbi: 1
# ron: 1
# intercept: 1
# smell: 1
# secon: 1
# egypt: 1
# footbal: 1
# occur: 1
# anni: 1
# asner: 1
# shelbi: 1
# township: 1
# citizen: 1
# sincer: 1
# banana: 1
# attach: 1
# casmer: 1
# mellow: 1
# backyard: 1
# bait: 1
# bossdaught: 1
# hall: 1
# muscl: 1
# tip: 1
# rubl: 1
# debat: 1
# solomon: 1
# terri: 1
# untold: 1
# quiet: 1
# vari: 1
# rang: 1
# easiest: 1
# scienc: 1
# packer: 1
# kindli: 1
# uneven: 1
# captain: 1
# cd: 1
# mon: 1
# lunch: 1
# mannix: 1
# filip: 1
# provost: 1
# tonal: 1
# apt: 1
# ab: 1
# stage: 1
# tab: 1
# grate: 1
# sherman: 1
# britney: 1
# pod: 1
# byei: 1
# angela: 1
# brew: 1
# guest: 1
# arrow: 1
# flower: 1
# employ: 1
# volum: 1
# tuesday: 1
# histon: 1
# heck: 1
# solv: 1
# standstil: 1
# stanc: 1
# descent: 1
# sibl: 1
# dial: 1
# fred: 1
# biker: 1
# itd: 1
# flug: 1
# mow: 1
# bleak: 1
# campfir: 1
# dealer: 1
# hung: 1
# byehi: 1
# karlen: 1
# explan: 1
# ohio: 1
# headsup: 1
# mold: 1
# affirm: 1
# lauren: 1
# nun: 1
# reserv: 1
# op: 1
# eighteenth: 1
# ellison: 1
# diss: 1
# smit: 1
# laxiti: 1
# winner: 1
# condol: 1
# clinton: 1
# reveal: 1
# santa: 1
# minton: 1
# mill: 1
# someday: 1
# truli: 1
# thatd: 1
# byeeleven: 1
# french: 1
# korea: 1
# admit: 1
# pacif: 1
# missouri: 1
# narrow: 1
# uppermost: 1
# employe: 1
# stimulu: 1
# salari: 1
# indec: 1
# esta: 1
# revers: 1
# buss: 1
# memento: 1
# missil: 1
# consist: 1
# trace: 1
# noon: 1
# pollin: 1
# ultim: 1
# delic: 1
# fungal: 1
# leg: 1
# dissip: 1
# commissari: 1
# comm: 1
# mutual: 1
# sposa: 1
# audiobook: 1
# nor: 1
# comed: 1
# supplement: 1
# danc: 1
# supermarket: 1
# insan: 1
# yll: 1
# humid: 1
# slam: 1
# phoenix: 1
# analyst: 1
# latina: 1
# parkland: 1
# teller: 1
# consumo: 1
# salut: 1
# muslim: 1
# protest: 1
# porn: 1
# cab: 1
# incorpor: 1
# replic: 1
# suitcas: 1
# underestim: 1
# stella: 1
# pursu: 1
# occurr: 1
# libyan: 1
# nicol: 1
# heat: 1
# delicaci: 1
# contradictori: 1
# infer: 1
# slip: 1
# alkamor: 1
# sayin: 1
# senoma: 1
# alaska: 1
# csaa: 1
# becam: 1
# reactor: 1
# italian: 1
# popular: 1
# commut: 1
# compliment: 1
# convent: 1
# imagist: 1
# sympathi: 1
# sadio: 1
# domest: 1
# yup: 1
# drill: 1
# astoria: 1
# hellothank: 1
# teres: 1
# resum: 1
# allendal: 1
# joseph: 1
# driver: 1
# sixteenth: 1
# wherefor: 1
# nationwid: 1
# bet: 1
# minus: 1
# cute: 1
# ed: 1
# toxin: 1
# halfway: 1
# wood: 1
# fif: 1
# byewhat: 1
# telecom: 1
# atlanta: 1
# par: 1
# pillowcas: 1
# nanci: 1
# sadi: 1
# lickin: 1
# tacoma: 1
# mcclement: 1
# reloc: 1
# danin: 1
# orient: 1
# commerc: 1
# gee: 1
# classroom: 1
# candl: 1
# vega: 1
# cocker: 1
# comport: 1
# garland: 1
# compon: 1
# inconsist: 1
# continent: 1
# equiti: 1
# misma: 1
# anonym: 1
# gossip: 1
# eunic: 1
# dude: 1
# cancela: 1
# hyla: 1
# spadaro: 1
# incommunicado: 1
# tothank: 1
# mistaken: 1
# somewhat: 1
# borrow: 1
# dunkel: 1
# burger: 1
# fund: 1
# forfeit: 1
# nsl: 1
# harder: 1
# streamlin: 1
# bird: 1
# strictli: 1
# stat: 1
# repetiti: 1
# petit: 1
# onto: 1
# describ: 1
# paul: 1
# passag: 1
# sox: 1
# marshal: 1
# paperwork: 1
# bigger: 1
# cream: 1
# seventeenth: 1
# ken: 1
# readjust: 1
# pariti: 1
# dark: 1
# tranc: 1
# foreclosur: 1
# wherev: 1
# misunderstood: 1
# terra: 1
# repeat: 1
# quarterli: 1
# flyer: 1
# renam: 1
# playboy: 1
# bora: 1
# cub: 1
# cleveland: 1
# detroit: 1
# radiu: 1
# el: 1
# visual: 1
# honda: 1
# recit: 1
# fell: 1
# joe: 1
# hockey: 1
# xar: 1
# rel: 1
# piti: 1
# dang: 1
# sandra: 1
# ensign: 1
# roadway: 1
# hartnel: 1
# mex: 1
# la: 1
# grey: 1
# corrupt: 1
# vantag: 1
# lo: 1
# angel: 1
# dialect: 1
# spanglish: 1
# joyc: 1
# byeoh: 1
# proport: 1
# dixi: 1
# stena: 1
# emerson: 1
# occas: 1
# harbor: 1
# celica: 1
# perman: 1
# collin: 1
# monica: 1
# northern: 1
# iraq: 1
# satur: 1
# messi: 1
# canali: 1
# christin: 1
# nicula: 1
# behl: 1
# basica: 1
# seller: 1
# whom: 1
# basketbal: 1
# permiss: 1
# hedonist: 1
# codi: 1
# fortun: 1
# pedest: 1
# unisi: 1
# thirtieth: 1
# isi: 1
# adher: 1
# persist: 1
# sc: 1
# au: 1
# robust: 1
# manilla: 1
# elementari: 1
# enemi: 1
# fatal: 1
# clinic: 1
# cal: 1
# polish: 1
# immov: 1
# hutch: 1
# sweati: 1
# matthew: 1
# assyria: 1
# dinwiddi: 1
# restaur: 1
# spent: 1
# decent: 1
# stomach: 1
# gym: 1
# inclement: 1
# lavern: 1
# insidi: 1
# thirtyhello: 1
# canesia: 1
# turkey: 1
# goodby: 1
# talkin: 1
# glass: 1
# mixer: 1
# theori: 1
# starz: 1
# alan: 1
# lander: 1
# pot: 1
# wherea: 1
# 10: 1
# length: 1
# mhmm: 1
# grandin: 1
# belt: 1
# notifi: 1
# cameron: 1
# ceo: 1
# dixon: 1
# rome: 1
# judg: 1
# crown: 1
# drone: 1
# forev: 1
# kovak: 1
# beta: 1
# fastest: 1
# groceri: 1
# nephew: 1
# style: 1
# unusu: 1
# alabama: 1
# europan: 1
# encor: 1
# denni: 1
# dual: 1
# valentin: 1
# tenement: 1
# overtim: 1
# lotto: 1
# pretend: 1
# roco: 1
# librari: 1
# opposit: 1
# versa: 1
# homer: 1
# prais: 1
# ident: 1
# draw: 1
# sketch: 1
# graphic: 1
# vegan: 1
# millennium: 1
# fridg: 1
# grand: 1
# homework: 1
# xbox: 1
# immobil: 1
# nut: 1
# rebat: 1
# rank: 1
# neither: 1
# smile: 1
# dana: 1
# coupon: 1
# cloth: 1
# kelli: 1
# demot: 1
# propos: 1
# david: 1
# folli: 1
# essenc: 1
# verif: 1
# shiloh: 1
# sociabl: 1
# factual: 1
# quad: 1
# section: 1
# guis: 1
# ensur: 1
# entireti: 1
# dispatch: 1
# fit: 1
# refus: 1
# wiser: 1
# tough: 1
# findabl: 1
# clearli: 1
# deceit: 1
# earth: 1
# staticki: 1
# versu: 1
# grandfath: 1
# christian: 1
# basi: 1
# themselv: 1
# stress: 1
# function: 1
# heidi: 1
# peer: 1
# chug: 1
# al: 1
# cart: 1
# offset: 1
# talli: 1
# aliv: 1
# carrier: 1
# okaypay: 1
# rectifi: 1
# seriou: 1
# significantli: 1
# spectrum: 1
# absurd: 1
# farther: 1
# specifi: 1
# seri: 1
# notori: 1
# career: 1
# spirit: 1
# speem: 1
# greatest: 1
# ming: 1
# squeak: 1
# reboot: 1
# norma: 1
# structur: 1
# rio: 1
# partnership: 1
# bobbi: 1
# shannon: 1
# sole: 1
# ditto: 1
# larg: 1
# brookwood: 1
# pero: 1
# ray: 1
# explor: 1
# minor: 1
# rhode: 1
# tim: 1
# transmit: 1
# peg: 1
# poetri: 1
# slowli: 1
# merci: 1
# byeso: 1
# kiera: 1
# remaind: 1
# super: 1
# sikh: 1
# octo: 1
# rebuild: 1
# reward: 1
# era: 1
# skeev: 1
# corner: 1
# script: 1
# extens: 1
# trick: 1
# loan: 1
# float: 1
# reclaim: 1
# upcom: 1
# portal: 1
# web: 1
# king: 1
# highway: 1
# di: 1
# art: 1
# lick: 1
# jans: 1
# bottl: 1
# wine: 1
# htc: 1
# deaf: 1
# deficit: 1
# perfer: 1
# compart: 1
# jeez: 1
# zone: 1
# mondo: 1
# automot: 1
# birthday: 1
# proven: 1
# mississippi: 1
# subsid: 1
# lept: 1
# registr: 1
# texin: 1
# grew: 1
# edit: 1
# beforehand: 1
# among: 1
# bondo: 1
# devier: 1
# cynthia: 1
# tween: 1
# callthank: 1
# peter: 1
# forgotten: 1
# dale: 1
# wwhere: 1
# cancer: 1
# cathol: 1
# behav: 1
# envelop: 1
# sensit: 1
# breath: 1
# rantoul: 1
# feeder: 1
# honey: 1
# hon: 1
# fay: 1
# bach: 1
# avenu: 1
# holder: 1
# collect: 1
# sammi: 1
# dormitori: 1
# mice: 1
# abshir: 1
# fi: 1
# district: 1
# nowyou: 1
# nomine: 1
# liber: 1
# foreign: 1
# noventicinco: 1
# trent: 1
# cuenta: 1
# cannist: 1
# engin: 1
# picki: 1
# architect: 1
# uniti: 1
# infirmari: 1
# genuin: 1
# religion: 1
# journalist: 1
# kinda: 1
# quintal: 1
# canoga: 1
# makinwa: 1
# tornado: 1
# remark: 1
# ringl: 1
# carolina: 1
# maryland: 1
# membership: 1
# jessica: 1
# timpanist: 1
# et: 1
# cetera: 1
# navi: 1
# nose: 1
# german: 1
# explos: 1
# dig: 1
# iraqi: 1
# scare: 1
# settl: 1
# inocul: 1
# ceil: 1
# commando: 1
# catll: 1
# wit: 1
# univers: 1
# gona: 1
# monetari: 1
# panic: 1
# phenomena: 1
# atlant: 1
# emidio: 1
# michaelson: 1
# parol: 1
# peremptorili: 1
# diesel: 1
# cinemark: 1
# lessen: 1
# incred: 1
# poison: 1
# amoroso: 1
# christoph: 1
# mainten: 1
# justthank: 1
# identif: 1
# debra: 1
# cari: 1
# devin: 1
# outthank: 1
# cheryl: 1
# retard: 1
# ash: 1
# niec: 1
# olga: 1
# actress: 1
# blond: 1
# pc: 1
# silenc: 1
# awhil: 1
# ace: 1
# status: 1
# psycholog: 1
# shift: 1
# autumn: 1
# permit: 1
# mega: 1
# somehow: 1
# amber: 1
# candac: 1
# sean: 1
# shahnawaz: 1
# song: 1
# brainless: 1
# curious: 1
# knowhi: 1
# info: 1
# rinaldi: 1
# coral: 1
# snack: 1
# payer: 1
# facad: 1
# condit: 1
# spur: 1
# failur: 1
# assumpt: 1
# marin: 1
# rommel: 1
# amir: 1
# appropri: 1
# disappoint: 1
# serious: 1
# hassl: 1
# sad: 1
# centuri: 1
# sexual: 1
# dearli: 1
# bandel: 1
# constantli: 1
# tempt: 1
# annual: 1
# deplor: 1
# methank: 1
# asia: 1
# miller: 1
# arkansa: 1
# hate: 1
# japan: 1
# cop: 1
# cuscon: 1
# pasveer: 1
# kale: 1
# ulis: 1
# israel: 1
# highest: 1
# susan: 1
# smote: 1
# patio: 1
# spat: 1
# paddl: 1
# conscienc: 1
# quickest: 1
# bizarr: 1
# tenney: 1
# welcomethank: 1
# phylli: 1
# stall: 1
# roughli: 1
# ski: 1
# similarli: 1
# bluelight: 1
# blanket: 1
# outag: 1
# ish: 1
# interfer: 1
# sun: 1
# melt: 1
# belong: 1
# flew: 1
# slap: 1
# nowbut: 1
# elma: 1
# kidll: 1
# familiar: 1
# maria: 1
# quantum: 1
# solo: 1
# rahmatullah: 1
# inter: 1
# sea: 1
# coaster: 1
# ronya: 1
# avia: 1
# cdma: 1
# amus: 1
# canal: 1
# urgent: 1
# guangli: 1
# magazin: 1
# insurg: 1
# momentum: 1
# pope: 1
# err: 1
# foment: 1
# mortuari: 1
# amic: 1
# tellin: 1
# roman: 1
# gather: 1
# island: 1
# romanc: 1
# titlist: 1
# stillwat: 1
# formal: 1
# assisi: 1
# milit: 1
# ocwen: 1
# minim: 1
# stern: 1
# formul: 1
# seattl: 1
# implic: 1
# median: 1
# mystic: 1
# completament: 1
# replica: 1
# tempera: 1
# medicaid: 1
# infrequ: 1
# deplet: 1
# holli: 1
# edward: 1
# leving: 1
# slavitt: 1
# weigh: 1
# hendersonvil: 1
# mole: 1
# reconfigur: 1
# unhelp: 1
# construct: 1
# rose: 1
# whether: 1
# quickli: 1
# whoever: 1
# casablanca: 1
# nicer: 1
# plow: 1
# kazillion: 1
# interact: 1
# ps: 1
# hero: 1
# allan: 1
# neat: 1
# immin: 1
# dash: 1
# curv: 1
# swap: 1
# junk: 1
# rca: 1
# heaven: 1
# spaghetti: 1
# mode: 1
# redo: 1
# shake: 1
# midwest: 1
# whitney: 1
# horror: 1
# preapprov: 1
# flick: 1
# youssou: 1
# bore: 1
# drum: 1
# tag: 1
# enforc: 1
# founder: 1
# wetn: 1
# suppli: 1
# contrast: 1
# stephen: 1
# jenni: 1
# oak: 1
# evid: 1
# chines: 1
# band: 1
# abc: 1
# approxim: 1
# middleburi: 1
# byebyethank: 1
# stark: 1
# helen: 1
# scene: 1
# mainstream: 1
# tradit: 1
# emerg: 1
# comparison: 1
# vh: 1
# intend: 1
# unbundl: 1
# circl: 1
# exit: 1
# handiest: 1
# sleep: 1
# sidetrack: 1
# introduct: 1
# chanba: 1
# rebroadcast: 1
# louder: 1
# espanyol: 1
# biggest: 1
# backslash: 1
# yell: 1
# project: 1
# sweet: 1
# trial: 1
# brian: 1
# owner: 1
# endur: 1
# viru: 1
# outcast: 1
# farm: 1
# playstat: 1
# varieti: 1
# besid: 1
# spous: 1
# ownership: 1
# discov: 1
# wishnet: 1
# briefli: 1
# constant: 1
# lap: 1
# sar: 1
# neighborhood: 1
# seamless: 1
# censor: 1
# dirti: 1
# minumum: 1
# unabl: 1
# bat: 1
# hybrid: 1
# workflow: 1
# workload: 1
# interst: 1
# idol: 1
# trail: 1
# allergi: 1
# energi: 1
# safeti: 1
# resign: 1
# background: 1
# triniti: 1
# hustl: 1
# war: 1
# counsel: 1
# alrightmed: 1
# biggi: 1
# gees: 1
# gaug: 1
# perki: 1
# ordinari: 1
# guard: 1
# terrilyn: 1
# foreman: 1
# healthi: 1
# ward: 1
# boston: 1
# supposedli: 1
# expos: 1
# bay: 1
# regner: 1
# flavor: 1
# metal: 1
# spn: 1
# zoo: 1
# goldfish: 1
# express: 1
# debbi: 1
# meantim: 1
# famou: 1
# bs: 1
# blew: 1
# defin: 1
# stroll: 1
# resid: 1
# survivor: 1
# disregard: 1
# resubmit: 1
# marti: 1
# non: 1
# responsehi: 1
# stigma: 1
# shoe: 1
# breckon: 1
# holler: 1
# fullest: 1
# retriev: 1
# diagnosi: 1
# metric: 1
# voter: 1
# wirelessli: 1
# desert: 1
# accumul: 1
# remedi: 1
# don: 1
# acquir: 1
# tielin: 1
# broker: 1
# advis: 1
# 7up: 1
# bag: 1
# fare: 1
# sacrific: 1
# devis: 1
# kristin: 1
# foss: 1
# advanti: 1
# chain: 1
# align: 1
# student: 1
# gene: 1
# reassess: 1
# nowthank: 1
# becki: 1
# barn: 1
# friendli: 1
# club: 1
# dorchest: 1
# northvil: 1
# rock: 1
# regret: 1
# creami: 1
# invent: 1
# billionair: 1
# prefectur: 1
# behalf: 1
# boss: 1
# sphere: 1
# ap: 1
# spoil: 1
# werent: 1
# junior: 1
# disney: 1
# xt: 1
# golf: 1
# plenti: 1
# closest: 1
# multipli: 1
# although: 1
# franchis: 1
# math: 1
# opportunist: 1
# bolt: 1
# pilot: 1
# annot: 1
# pondel: 1
# bunch: 1
# global: 1
# breakdown: 1
# homeservic: 1
# thoma: 1
# bori: 1
# uniqu: 1
# nail: 1
# scott: 1
# byefor: 1
# sherri: 1
# jim: 1
# donald: 1
# numbersto: 1
# gender: 1
# defend: 1
# internist: 1
# pain: 1
# venic: 1
# floress: 1
# span: 1
# workout: 1
# ban: 1
# rene: 1
# ring: 1
# handset: 1
# perhap: 1
# depos: 1
# brace: 1
# freakiest: 1
# nurs: 1
# rod: 1
# raymond: 1
# reader: 1
# recod: 1
# wast: 1
# fcc: 1
# jerri: 1
# slower: 2
# soonest: 2
# west: 2
# boat: 2
# phd: 2
# tight: 2
# suit: 2
# tina: 2
# dream: 2
# eventu: 2
# silent: 2
# er: 2
# stupid: 2
# baggag: 2
# washington: 2
# crap: 2
# mr: 2
# shell: 2
# bonu: 2
# bowl: 2
# notat: 2
# ground: 2
# shortli: 2
# peac: 2
# male: 2
# yyou: 2
# execut: 2
# degre: 2
# drug: 2
# identifi: 2
# nothin: 2
# avoid: 2
# mission: 2
# umm: 2
# nois: 2
# negoti: 2
# against: 2
# focus: 2
# tend: 2
# sold: 2
# difficult: 2
# deduct: 2
# yo: 2
# motor: 2
# natur: 2
# bomb: 2
# modifi: 2
# everywher: 2
# felt: 2
# younger: 2
# excit: 2
# jess: 2
# convers: 2
# bid: 2
# repli: 2
# reconnect: 2
# mckinney: 2
# callback: 2
# tan: 2
# board: 2
# flip: 2
# mckenni: 2
# bread: 2
# bond: 2
# discoveri: 2
# crime: 2
# short: 2
# compens: 2
# religi: 2
# pant: 2
# brandi: 2
# indianapoli: 2
# bravo: 2
# greater: 2
# pastor: 2
# zip: 2
# mainli: 2
# danni: 2
# j: 2
# nexu: 2
# resend: 2
# classic: 2
# lincoln: 2
# fri: 2
# drink: 2
# necessari: 2
# post: 2
# ball: 2
# mo: 2
# occasion: 2
# pair: 2
# imag: 2
# twentieth: 2
# campaign: 2
# cheapest: 2
# draft: 2
# pal: 2
# carl: 2
# row: 2
# consent: 2
# cloudi: 2
# fish: 2
# debit: 2
# council: 2
# instant: 2
# everyday: 2
# bar: 2
# sex: 2
# calendar: 2
# tune: 2
# ga: 2
# brows: 2
# satisfact: 2
# opt: 2
# feedback: 2
# oper: 2
# space: 2
# movin: 2
# comedi: 2
# syrian: 2
# nowher: 2
# disappear: 2
# design: 2
# appar: 2
# blame: 2
# flight: 2
# smartphon: 2
# freak: 2
# penni: 2
# bump: 2
# immedi: 2
# swing: 2
# graduat: 2
# recycl: 2
# men: 2
# secular: 2
# mandatori: 2
# independ: 2
# parad: 2
# mayor: 2
# angri: 2
# pressur: 2
# canada: 2
# competit: 2
# introduc: 2
# scandal: 2
# armi: 2
# proper: 2
# scale: 2
# attack: 2
# innoc: 2
# floor: 2
# sampl: 2
# reli: 2
# player: 2
# entitl: 2
# franci: 2
# conolli: 2
# canist: 2
# western: 2
# sunday: 2
# cindi: 2
# lay: 2
# suspect: 2
# unanim: 2
# human: 2
# militari: 2
# suddenli: 2
# daniel: 2
# recess: 2
# valeri: 2
# ocean: 2
# infin: 2
# sec: 2
# orlando: 2
# plant: 2
# retail: 2
# film: 2
# committe: 2
# titl: 2
# medal: 2
# organ: 2
# luck: 2
# invoic: 2
# indoor: 2
# carol: 2
# planet: 2
# elmo: 2
# confer: 2
# gimm: 2
# spring: 2
# cri: 2
# yanke: 2
# shop: 2
# packet: 2
# till: 2
# fire: 2
# met: 2
# receipt: 2
# rick: 2
# concept: 2
# sooner: 2
# brand: 2
# empti: 2
# penal: 2
# incorrectli: 2
# tire: 2
# salad: 2
# tier: 2
# remind: 2
# mile: 2
# near: 2
# anytim: 2
# shock: 2
# fairli: 2
# storag: 2
# eras: 2
# split: 2
# author: 2
# individu: 2
# frame: 2
# ladi: 2
# crack: 2
# arizona: 2
# condo: 2
# forth: 2
# celebr: 2
# master: 2
# anti: 2
# decis: 2
# comma: 2
# chose: 2
# instrument: 2
# capit: 2
# horribl: 2
# carri: 2
# squar: 2
# connector: 2
# theater: 2
# suscept: 2
# saturday: 2
# array: 2
# averag: 2
# cellphon: 2
# googl: 2
# confront: 2
# maze: 2
# spell: 2
# alert: 2
# fantast: 2
# calm: 2
# georgia: 2
# entri: 2
# meat: 2
# lack: 2
# partner: 2
# size: 2
# nebraska: 2
# pole: 2
# evil: 2
# ridicul: 2
# afterward: 2
# interrupt: 2
# savannah: 2
# iphon: 2
# cheap: 2
# ellen: 2
# girlfriend: 2
# laura: 2
# youthank: 2
# understood: 2
# audio: 2
# broken: 2
# clue: 2
# portion: 2
# encourag: 2
# challeng: 2
# ego: 2
# grant: 2
# bust: 2
# smaller: 2
# seed: 2
# adaptor: 2
# refund: 2
# conveni: 2
# infect: 2
# known: 2
# benefici: 2
# lauri: 2
# improv: 2
# serena: 2
# gun: 2
# numer: 2
# lawyer: 2
# silver: 2
# nick: 2
# coverag: 2
# tech: 2
# arriv: 2
# reschedul: 2
# forc: 2
# disciplin: 2
# cross: 2
# max: 2
# boxer: 2
# sam: 2
# target: 2
# knowledg: 2
# greatli: 2
# cruis: 2
# london: 2
# asian: 2
# hire: 2
# outrag: 2
# manni: 2
# latest: 2
# hun: 2
# danger: 2
# mac: 2
# england: 2
# mid: 2
# nato: 2
# lone: 2
# linda: 2
# elect: 2
# vin: 2
# blood: 2
# eighth: 2
# favor: 2
# beach: 2
# associ: 2
# sudden: 2
# pre: 2
# assur: 2
# dish: 2
# transpir: 2
# jacksonvil: 2
# montana: 2
# granddaught: 2
# theyd: 2
# japon: 2
# pray: 2
# amid: 2
# pad: 2
# senat: 2
# integr: 2
# electr: 2
# assess: 2
# kansa: 2
# companion: 2
# lillian: 2
# frankli: 2
# form: 2
# brooklyn: 2
# media: 2
# okaythank: 2
# smithsonian: 2
# tom: 2
# enabl: 2
# hunt: 2
# shirt: 2
# pend: 2
# finger: 2
# factor: 2
# otherwis: 2
# affin: 2
# stephani: 2
# jason: 2
# nbc: 2
# cb: 2
# patricia: 2
# router: 2
# rout: 2
# earliest: 2
# microphon: 2
# fourteenth: 2
# nation: 2
# recap: 2
# courtesi: 2
# softwar: 2
# byeby: 2
# ford: 2
# geek: 2
# plane: 2
# alayna: 2
# downtown: 2
# unplug: 2
# crew: 2
# stair: 2
# transmiss: 2
# experienc: 2
# exhaust: 2
# shoot: 2
# barnhart: 2
# hotmail: 2
# effort: 2
# teenag: 2
# divid: 2
# proceed: 2
# paint: 3
# core: 3
# cycl: 3
# provis: 3
# daddi: 3
# prevent: 3
# site: 3
# wide: 3
# attic: 3
# garag: 3
# warn: 3
# fail: 3
# soup: 3
# hasnt: 3
# rosalyn: 3
# health: 3
# rice: 3
# glitch: 3
# inconveni: 3
# backdat: 3
# tex: 3
# vice: 3
# scream: 3
# laptop: 3
# ninth: 3
# server: 3
# won: 3
# central: 3
# eastern: 3
# ignit: 3
# maximum: 3
# contractor: 3
# stori: 3
# usag: 3
# track: 3
# oppos: 3
# amend: 3
# properti: 3
# virtual: 3
# event: 3
# batteri: 3
# satellit: 3
# pet: 3
# client: 3
# introductori: 3
# lastli: 3
# yearli: 3
# pardon: 3
# ooh: 3
# surpris: 3
# aint: 3
# warm: 3
# disabl: 3
# involv: 3
# count: 3
# byegood: 3
# lane: 3
# leas: 3
# tick: 3
# suggest: 3
# safe: 3
# decad: 3
# recogn: 3
# pound: 3
# fresh: 3
# featur: 3
# alter: 3
# luckili: 3
# athlet: 3
# twice: 3
# yesterday: 3
# gotta: 3
# reoccur: 3
# sentiment: 3
# gmail: 3
# whichev: 3
# tear: 3
# block: 3
# dalla: 3
# present: 3
# expenditur: 3
# cord: 3
# dvd: 3
# touch: 3
# color: 3
# white: 3
# speaker: 3
# mm: 3
# screw: 3
# reflect: 3
# inbox: 3
# solid: 3
# topic: 3
# fill: 3
# illeg: 3
# women: 3
# tournament: 3
# semest: 3
# republican: 3
# holiday: 3
# necessarili: 3
# window: 3
# medic: 3
# incid: 3
# san: 3
# anim: 3
# heart: 3
# minu: 3
# upper: 3
# california: 3
# china: 3
# realiti: 3
# purpos: 3
# valuabl: 3
# verizon: 3
# tower: 3
# finidi: 3
# quint: 3
# insist: 3
# dorothi: 3
# border: 3
# tonight: 3
# tremend: 3
# ice: 3
# advertis: 3
# temporari: 3
# discontinu: 3
# theyv: 3
# sever: 3
# transit: 3
# fair: 3
# written: 3
# honor: 3
# directv: 3
# daili: 3
# enhanc: 3
# pop: 3
# nba: 3
# hispan: 3
# cultur: 3
# christina: 3
# mass: 3
# grab: 3
# lisa: 3
# overal: 3
# mad: 3
# speech: 3
# declin: 3
# fan: 3
# walmart: 3
# hallmark: 3
# eagl: 3
# aw: 3
# shut: 3
# everyon: 3
# claim: 3
# illinoi: 3
# oil: 3
# feder: 3
# mike: 3
# serv: 3
# industri: 3
# upset: 3
# relat: 3
# releas: 3
# syria: 3
# ex: 3
# entiti: 3
# poor: 3
# face: 3
# behind: 3
# minnesota: 3
# worst: 3
# teacher: 3
# alon: 3
# nh: 3
# lesson: 3
# model: 3
# util: 3
# lead: 3
# suffici: 3
# japanes: 3
# hill: 3
# blah: 3
# highli: 3
# marri: 3
# elig: 3
# steven: 3
# beyond: 3
# round: 3
# wrote: 3
# gay: 3
# terabyt: 3
# detect: 3
# diagnos: 3
# fortnight: 3
# penalti: 3
# reimburs: 3
# disclaim: 3
# slow: 4
# awesom: 4
# spoke: 4
# stock: 4
# re: 4
# wors: 4
# pattern: 4
# ran: 4
# beauti: 4
# gate: 4
# doubt: 4
# indic: 4
# bed: 4
# stick: 4
# hurt: 4
# brother: 4
# lie: 4
# vacat: 4
# fear: 4
# exercis: 4
# fax: 4
# teen: 4
# histori: 4
# physic: 4
# handl: 4
# aaa: 4
# evalu: 4
# financ: 4
# fight: 4
# abov: 4
# bless: 4
# medicin: 4
# strain: 4
# cheaper: 4
# somewher: 4
# clarifi: 4
# owe: 4
# via: 4
# threat: 4
# often: 4
# emot: 4
# doctor: 4
# consum: 4
# bob: 4
# error: 4
# toward: 4
# serial: 4
# flash: 4
# brought: 4
# senior: 4
# freez: 4
# built: 4
# tape: 4
# wed: 4
# z: 4
# prove: 4
# cloud: 4
# insul: 4
# smith: 4
# meant: 4
# class: 4
# billion: 4
# input: 4
# shouldnt: 4
# regardless: 4
# seat: 4
# upon: 4
# lock: 4
# grow: 4
# suspend: 4
# benefit: 4
# particip: 4
# lucki: 4
# impress: 4
# eleventh: 4
# matur: 4
# earn: 4
# mental: 4
# focu: 4
# desk: 4
# indian: 4
# woman: 4
# share: 4
# kim: 4
# septemb: 4
# tenth: 4
# renew: 4
# horizon: 4
# rain: 4
# fifth: 4
# accid: 4
# michael: 4
# entic: 4
# mexico: 4
# terror: 4
# bought: 4
# closer: 4
# subscrib: 4
# train: 4
# betti: 4
# elimin: 4
# guid: 4
# land: 4
# languag: 4
# caught: 4
# implement: 4
# lake: 4
# pen: 4
# jame: 4
# weird: 4
# thirteenth: 4
# multi: 4
# cap: 4
# legal: 4
# multipl: 4
# europ: 4
# premier: 4
# fault: 4
# default: 4
# kay: 4
# richard: 4
# confus: 4
# trust: 4
# afraid: 4
# entir: 4
# imagin: 4
# templ: 4
# trailer: 4
# profession: 4
# miami: 4
# boomerang: 4
# bloomberg: 4
# kidnap: 4
# jean: 4
# capabl: 4
# respond: 5
# wire: 5
# age: 5
# qualiti: 5
# john: 5
# jackson: 5
# attent: 5
# accord: 5
# tenni: 5
# kick: 5
# terrorist: 5
# prepar: 5
# such: 5
# gotten: 5
# oclock: 5
# valid: 5
# resolv: 5
# replac: 5
# jump: 5
# commerci: 5
# fli: 5
# incent: 5
# except: 5
# wise: 5
# pack: 5
# radio: 5
# kept: 5
# publish: 5
# bare: 5
# walk: 5
# loyal: 5
# act: 5
# mama: 5
# cartoon: 5
# honestli: 5
# prompt: 5
# brown: 5
# map: 5
# direct: 5
# lost: 5
# manag: 5
# wayn: 5
# practic: 5
# uhm: 5
# unit: 5
# success: 5
# common: 5
# mess: 5
# ima: 5
# accent: 5
# key: 5
# tennesse: 5
# further: 5
# insid: 5
# nope: 5
# across: 5
# samsung: 5
# notif: 5
# recal: 5
# trade: 5
# lord: 5
# incom: 5
# anybodi: 5
# budget: 5
# simpl: 5
# element: 5
# airport: 5
# comment: 5
# econom: 5
# femal: 5
# august: 5
# netflix: 5
# 6: 5
# feet: 5
# extent: 5
# similar: 5
# bank: 5
# port: 5
# particularli: 5
# leagu: 5
# newer: 5
# fort: 5
# research: 5
# comp: 5
# websit: 5
# liter: 5
# born: 5
# arent: 5
# fifteenth: 5
# search: 5
# friday: 5
# weekend: 5
# eh: 5
# quot: 5
# promo: 5
# gosh: 5
# delet: 5
# cook: 5
# modern: 5
# sale: 6
# steve: 6
# troubleshoot: 6
# true: 6
# ok: 6
# terribl: 6
# expand: 6
# situat: 6
# respons: 6
# colleg: 6
# posit: 6
# none: 6
# worth: 6
# properli: 6
# f: 6
# wish: 6
# clear: 6
# calcul: 6
# parti: 6
# jack: 6
# dad: 6
# hand: 6
# statu: 6
# gain: 6
# world: 6
# easier: 6
# rais: 6
# town: 6
# throne: 6
# jacki: 6
# instruct: 6
# cast: 6
# becom: 6
# amaz: 6
# determin: 6
# video: 6
# initi: 6
# south: 6
# catch: 6
# ya: 6
# decreas: 6
# exchang: 6
# anthoni: 6
# asid: 6
# below: 6
# accept: 6
# unknown: 6
# correctli: 6
# blink: 6
# valu: 6
# directli: 6
# studi: 6
# children: 6
# opportun: 6
# abil: 6
# higher: 6
# exist: 6
# corpor: 6
# throw: 6
# economi: 6
# east: 6
# mexican: 6
# amanda: 6
# travel: 6
# command: 6
# sick: 6
# futur: 6
# rise: 6
# restor: 6
# print: 6
# gentleman: 6
# nfl: 6
# inning: 6
# assum: 6
# tabl: 6
# net: 6
# content: 6
# obvious: 6
# balanc: 6
# protect: 6
# smoke: 6
# previous: 6
# upstair: 6
# drop: 6
# match: 6
# chri: 7
# megabit: 7
# anyon: 7
# percent: 7
# truck: 7
# awar: 7
# afternoon: 7
# document: 7
# brief: 7
# patient: 7
# distanc: 7
# standard: 7
# car: 7
# repres: 7
# shot: 7
# countri: 7
# die: 7
# side: 7
# fun: 7
# novemb: 7
# octob: 7
# church: 7
# favorit: 7
# vehicl: 7
# creat: 7
# lowest: 7
# couldnt: 7
# afford: 7
# retir: 7
# refer: 7
# control: 7
# meet: 7
# visa: 7
# faster: 7
# specif: 7
# mari: 7
# product: 7
# night: 7
# blue: 7
# survey: 7
# regard: 7
# child: 7
# em: 7
# prorat: 7
# india: 7
# flat: 7
# cnn: 7
# english: 7
# north: 7
# presid: 7
# latino: 7
# rather: 7
# music: 7
# corn: 7
# break: 7
# fall: 7
# unfortun: 7
# christma: 7
# 8: 7
# piec: 7
# red: 7
# begin: 7
# ticket: 8
# hang: 8
# mine: 8
# word: 8
# tablet: 8
# action: 8
# water: 8
# pro: 8
# mom: 8
# kn: 8
# parent: 8
# babi: 8
# heard: 8
# patienc: 8
# hell: 8
# laugh: 8
# cut: 8
# public: 8
# hot: 8
# excus: 8
# remain: 8
# adapt: 8
# partial: 8
# sister: 8
# w: 8
# rent: 8
# low: 8
# knew: 8
# slash: 8
# byethank: 8
# strang: 8
# commit: 8
# select: 8
# 3: 8
# bodi: 8
# bedroom: 8
# letter: 8
# request: 8
# exampl: 8
# stand: 8
# recommend: 8
# exact: 8
# american: 8
# page: 8
# major: 8
# instanc: 8
# howev: 8
# forget: 8
# roku: 8
# secondari: 8
# fox: 8
# tomorrow: 9
# forward: 9
# camera: 9
# typic: 9
# primari: 9
# given: 9
# saw: 9
# front: 9
# station: 9
# previou: 9
# kill: 9
# center: 9
# motiv: 9
# fast: 9
# small: 9
# member: 9
# recur: 9
# mostli: 9
# mark: 9
# honest: 9
# crazi: 9
# michigan: 9
# subscript: 9
# guarante: 9
# quarter: 9
# basebal: 9
# york: 9
# spot: 9
# young: 9
# intern: 9
# pocket: 9
# april: 9
# telephon: 9
# sell: 9
# downgrad: 9
# support: 10
# megabyt: 10
# social: 10
# file: 10
# glad: 10
# wanna: 10
# u: 10
# ne: 10
# food: 10
# snow: 10
# 2: 10
# build: 10
# enter: 10
# wifi: 10
# advanc: 10
# outlet: 10
# statement: 10
# detail: 10
# plug: 10
# weather: 10
# complain: 10
# winter: 10
# chicago: 10
# hard: 10
# affect: 10
# expens: 10
# yahoo: 10
# 7: 10
# appear: 10
# sourc: 10
# gener: 10
# adjust: 10
# polit: 10
# mother: 10
# idea: 10
# view: 10
# requir: 10
# loyalti: 10
# excel: 10
# choic: 10
# purchas: 10
# rid: 10
# load: 10
# technic: 11
# girl: 11
# gotcha: 11
# light: 11
# wireless: 11
# supervisor: 11
# boy: 11
# demand: 11
# funni: 11
# news: 11
# yourself: 11
# refresh: 11
# push: 11
# opinion: 11
# g: 11
# head: 11
# educ: 11
# seem: 11
# nobodi: 11
# half: 11
# verbal: 11
# period: 11
# hook: 11
# matter: 11
# applic: 11
# equal: 11
# gone: 11
# finish: 11
# technolog: 11
# showtim: 11
# return: 11
# book: 11
# compar: 11
# america: 11
# pleasur: 11
# spanish: 11
# whenev: 12
# reach: 12
# youd: 12
# earlier: 12
# job: 12
# pictur: 12
# fourth: 12
# cover: 12
# note: 12
# certain: 12
# insur: 12
# special: 12
# level: 12
# monday: 12
# daughter: 12
# experi: 12
# along: 12
# air: 12
# separ: 12
# simpli: 12
# origin: 12
# restart: 12
# eat: 12
# qualifi: 12
# contest: 12
# perform: 12
# black: 13
# everybodi: 13
# mister: 13
# summer: 13
# y: 13
# wh: 13
# minimum: 13
# sort: 13
# bad: 13
# soon: 13
# continu: 13
# lose: 13
# door: 13
# unless: 13
# rental: 13
# anywher: 13
# later: 13
# learn: 13
# cinemax: 13
# consid: 13
# street: 13
# regist: 13
# promis: 13
# forgot: 13
# wall: 14
# notic: 14
# schedul: 14
# write: 14
# cat: 14
# apart: 14
# especi: 14
# worri: 14
# accur: 14
# outsid: 14
# drive: 14
# indiana: 14
# market: 14
# user: 14
# decid: 14
# enrol: 14
# husband: 14
# instead: 14
# downstair: 14
# report: 15
# appoint: 15
# fulli: 15
# found: 15
# lineup: 15
# quit: 15
# visit: 15
# agent: 15
# hey: 15
# troubl: 15
# chanc: 15
# self: 15
# huh: 15
# instal: 15
# top: 15
# smart: 15
# step: 15
# expect: 15
# fact: 15
# contact: 15
# paperless: 15
# green: 15
# singl: 15
# gave: 15
# ship: 15
# room: 15
# test: 16
# citi: 16
# wrong: 16
# taken: 16
# offic: 16
# process: 16
# due: 16
# commun: 16
# enough: 16
# itself: 16
# local: 16
# theyll: 16
# road: 16
# thatll: 16
# son: 16
# sit: 16
# buck: 16
# cold: 16
# code: 16
# each: 16
# cool: 16
# certainli: 16
# texa: 16
# ago: 17
# base: 17
# stop: 17
# big: 17
# depart: 17
# limit: 17
# answer: 17
# februari: 17
# late: 17
# amount: 17
# explain: 17
# school: 17
# god: 17
# somebodi: 17
# sixteen: 17
# import: 17
# log: 17
# friend: 17
# readi: 17
# reduc: 17
# bear: 17
# older: 17
# busi: 17
# reset: 18
# rest: 18
# easi: 18
# paper: 18
# estim: 18
# submit: 18
# buy: 18
# must: 18
# region: 18
# switch: 18
# anymor: 18
# final: 18
# absolut: 18
# k: 18
# download: 18
# particular: 18
# francisco: 18
# gig: 18
# between: 19
# power: 19
# dog: 19
# main: 19
# fourteen: 19
# decemb: 19
# govern: 19
# hd: 19
# expend: 19
# left: 19
# januari: 19
# took: 19
# expir: 19
# subject: 19
# state: 19
# mention: 19
# recent: 19
# 4: 19
# middl: 19
# 9: 19
# court: 20
# million: 20
# figur: 20
# type: 20
# screen: 20
# entertain: 20
# third: 20
# togeth: 20
# discuss: 20
# believ: 20
# copi: 20
# depend: 20
# bottom: 20
# myself: 20
# normal: 21
# fix: 21
# area: 21
# apolog: 21
# famili: 21
# v: 21
# seen: 21
# wouldnt: 21
# solut: 21
# allow: 21
# data: 21
# store: 21
# alrighti: 21
# park: 21
# button: 21
# sens: 21
# hope: 22
# morn: 22
# team: 22
# transfer: 22
# possibl: 22
# advantag: 22
# dure: 22
# love: 22
# program: 22
# mobil: 22
# 5: 22
# longer: 22
# florida: 22
# roll: 23
# quick: 23
# both: 23
# usual: 23
# point: 23
# locat: 23
# leav: 23
# cannot: 23
# press: 23
# wow: 23
# espn: 23
# sometim: 24
# polici: 24
# full: 24
# captur: 24
# n: 24
# unlimit: 24
# paid: 24
# appli: 24
# kid: 24
# life: 24
# listen: 24
# broadcast: 24
# without: 24
# hit: 24
# away: 24
# autom: 25
# blast: 25
# uhhuh: 25
# r: 25
# pass: 25
# wont: 25
# deal: 25
# march: 25
# high: 25
# compani: 25
# nice: 25
# appl: 25
# effect: 25
# televis: 25
# digit: 26
# someon: 26
# p: 26
# perfect: 26
# cancel: 26
# happi: 26
# far: 26
# close: 26
# seventeen: 26
# spend: 27
# mind: 27
# updat: 27
# automat: 27
# weve: 27
# summari: 27
# doubl: 27
# isnt: 27
# juli: 27
# disconnect: 28
# eleven: 28
# made: 28
# onlin: 28
# 1: 28
# list: 28
# interest: 28
# hour: 29
# feel: 29
# enjoy: 29
# hear: 29
# ever: 29
# care: 29
# wasnt: 29
# open: 29
# anyway: 29
# bit: 29
# card: 29
# speak: 30
# sound: 30
# id: 30
# cours: 30
# cell: 30
# choos: 30
# yep: 31
# date: 31
# case: 31
# cost: 31
# welcom: 31
# l: 31
# wonder: 31
# starter: 31
# activ: 31
# voic: 31
# within: 31
# thirteen: 31
# mlb: 31
# comput: 32
# might: 32
# eighteen: 32
# earli: 32
# week: 33
# increas: 33
# technician: 33
# hous: 33
# man: 33
# bundl: 33
# run: 34
# reason: 34
# goe: 34
# m: 34
# least: 34
# june: 34
# speed: 35
# extend: 35
# b: 35
# under: 35
# coupl: 36
# d: 36
# issu: 36
# past: 36
# appreci: 36
# either: 36
# mani: 36
# hello: 37
# most: 37
# real: 37
# option: 37
# secur: 37
# concern: 37
# premium: 37
# around: 37
# devic: 37
# thought: 37
# miss: 38
# rememb: 38
# o: 38
# term: 38
# upgrad: 38
# remov: 38
# game: 38
# less: 38
# havent: 39
# old: 39
# tripl: 39
# place: 39
# live: 39
# wife: 39
# ad: 39
# lower: 39
# suppos: 40
# follow: 40
# these: 40
# until: 40
# termin: 40
# while: 41
# itll: 41
# pretti: 41
# exactli: 41
# youv: 41
# x: 41
# link: 41
# yet: 41
# pull: 42
# com: 42
# mail: 42
# signal: 43
# xfiniti: 44
# came: 44
# though: 44
# save: 44
# remot: 44
# record: 44
# her: 45
# alway: 45
# complet: 45
# own: 45
# total: 46
# extrem: 46
# dot: 46
# s: 46
# access: 46
# am: 46
# bring: 46
# sent: 47
# who: 47
# wait: 47
# h: 47
# person: 48
# t: 48
# whole: 48
# noth: 48
# per: 48
# almost: 48
# season: 48
# find: 49
# confirm: 49
# money: 49
# password: 49
# end: 50
# add: 50
# pick: 51
# plu: 51
# better: 51
# fine: 51
# great: 51
# click: 51
# stay: 51
# inform: 51
# read: 51
# done: 52
# plan: 52
# part: 53
# els: 53
# nineteen: 53
# move: 53
# probabl: 54
# sir: 54
# extra: 54
# definit: 55
# youll: 55
# play: 55
# twelv: 55
# never: 56
# provid: 56
# regular: 56
# stuff: 56
# hbo: 56
# payment: 57
# caus: 57
# best: 58
# verifi: 58
# network: 58
# long: 58
# turn: 58
# monthli: 58
# assist: 59
# credit: 59
# c: 61
# few: 62
# hi: 62
# hm: 62
# auto: 62
# fifteen: 63
# guess: 64
# avail: 64
# discount: 64
# him: 65
# veri: 65
# thousand: 65
# cent: 65
# review: 65
# current: 66
# anoth: 66
# contract: 66
# doesnt: 67
# free: 67
# whatev: 68
# told: 68
# sign: 68
# went: 69
# basic: 69
# price: 69
# mayb: 70
# their: 71
# star: 71
# everi: 72
# agreement: 72
# agre: 72
# addit: 74
# sixti: 75
# kind: 75
# onc: 75
# stream: 75
# help: 76
# peopl: 76
# custom: 76
# hold: 76
# happen: 77
# modem: 78
# messag: 78
# understand: 78
# movi: 78
# guy: 78
# next: 79
# lot: 79
# sorri: 79
# ive: 80
# than: 81
# should: 81
# system: 81
# ha: 81
# bye: 81
# differ: 81
# text: 82
# connect: 83
# cant: 83
# doe: 85
# sinc: 86
# sport: 86
# offer: 86
# problem: 87
# set: 87
# prefer: 87
# talk: 88
# didnt: 88
# first: 90
# maam: 90
# minut: 91
# us: 92
# fee: 93
# keep: 94
# ask: 94
# question: 94
# e: 94
# may: 95
# eighti: 95
# receiv: 96
# line: 97
# after: 97
# seventi: 98
# anyth: 99
# second: 100
# theyr: 100
# comcast: 105
# moment: 106
# even: 106
# zero: 106
# through: 106
# last: 107
# rate: 107
# same: 108
# gonna: 109
# realli: 109
# off: 109
# littl: 111
# again: 111
# down: 111
# address: 111
# where: 111
# pleas: 112
# approv: 112
# home: 112
# too: 113
# dvr: 113
# watch: 114
# everyth: 114
# she: 115
# our: 115
# whi: 116
# tell: 116
# charg: 116
# show: 116
# work: 117
# start: 117
# correct: 117
# includ: 118
# way: 121
# tax: 121
# been: 122
# those: 122
# abl: 122
# send: 122
# other: 124
# promot: 124
# cabl: 124
# by: 124
# thirti: 126
# could: 127
# sure: 128
# seven: 131
# ahead: 131
# alreadi: 131
# new: 132
# day: 134
# today: 135
# over: 137
# equip: 137
# forti: 140
# which: 140
# someth: 142
# good: 142
# had: 143
# put: 143
# befor: 147
# into: 147
# also: 148
# number: 148
# eight: 148
# onli: 149
# fifti: 149
# check: 155
# some: 155
# name: 157
# still: 158
# more: 159
# ten: 160
# mhm: 162
# tri: 166
# make: 169
# email: 171
# use: 174
# think: 177
# ill: 179
# thing: 180
# an: 181
# need: 184
# phone: 185
# six: 191
# year: 191
# hundr: 192
# ani: 192
# from: 197
# give: 198
# ah: 198
# did: 205
# chang: 207
# packag: 214
# much: 216
# actual: 216
# said: 217
# box: 220
# tv: 220
# mean: 222
# he: 222
# were: 223
# them: 226
# take: 227
# pay: 231
# how: 233
# order: 233
# back: 241
# internet: 243
# about: 247
# time: 247
# look: 248
# come: 260
# three: 267
# as: 267
# bill: 268
# account: 269
# got: 270
# four: 288
# say: 289
# call: 290
# channel: 292
# twenti: 294
# nineti: 296
# when: 309
# out: 311
# thank: 324
# ye: 324
# will: 332
# servic: 341
# month: 349
# are: 354
# five: 358
# here: 359
# oh: 366
# alright: 375
# nine: 389
# would: 407
# all: 409
# let: 414
# there: 430
# want: 434
# they: 449
# up: 451
# dollar: 459
# no: 460
# well: 460
# wa: 471
# then: 475
# two: 477
# or: 489
# see: 497
# dont: 503
# becaus: 504
# at: 507
# right: 507
# not: 542
# now: 557
# my: 610
# but: 641
# yeah: 647
# like: 653
# get: 681
# uh: 692
# we: 698
# with: 754
# know: 758
# im: 779
# if: 781
# do: 796
# me: 798
# can: 798
# be: 836
# thi: 858
# what: 862
# just: 871
# go: 973
# in: 977
# um: 1008
# of: 1051
# one: 1066
# on: 1133
# have: 1278
# is: 1334
# for: 1360
# okay: 1571
# so: 1683
# your: 1778
# a: 2085
# it: 2667
# and: 2926
# that: 2940
# to: 3244
# i: 3604
# the: 4268
# you: 4369

# %%
charge_keys = ['bill', 'billing', 'billed', 'tax', 'taxes', 'taxed',
               'price', 'rate', 'rates'
              ] 

gen_package_keys = ['bundle', 'bundles',  'bundled', 'promotion', 'promotions', 'promotional', 
                    'premium', 'premiums', 'service', 'services', 'serviceable', 'unlimited', 
                    'basic', 'starter', 'extreme', 'equipment', 'equipments'
                   ]

finalization_keys = ['order', 'ordering', 'approve', 'approved', 'approval', 
                     'reviewed', 'reviewing', 'validation']

additional_xh_keys = ['homeservices']

additional_stream_keys = ['livestreaming', 'streamlined']

additional_wifi_keys = ['online', 'connection', 'connections']

additional_phone_keys = ['voice']

additional_tv_keys = ['sport', 'sports', 'sporting'] 

new_keys = charge_keys + gen_package_keys + finalization_keys + additional_stream_keys + \
           additional_wifi_keys + additional_phone_keys + additional_tv_keys 

print(new_keys)
print(len(new_keys))
# Out:
# ['bill', 'billing', 'billed', 'tax', 'taxes', 'taxed', 'price', 'rate', 'rates', 'bundle', 'bundles', 'bundled', 'promotion', 'promotions', 'promotional', 'premium', 'premiums', 'service', 'services', 'serviceable', 'unlimited', 'basic', 'starter', 'extreme', 'equipment', 'equipments', 'order', 'ordering', 'approve', 'approved', 'approval', 'reviewed', 'reviewing', 'validation', 'livestreaming', 'streamlined', 'online', 'connection', 'connections', 'voice', 'sport', 'sports', 'sporting']
# 43
